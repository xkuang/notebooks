# %%
import tensorflow as tf
import xml
import numpy as np
from pylab import *
# %matplotlib inline
import xml.etree.ElementTree as ET
import cv2
import os
from matplotlib import patches
from random import shuffle, randint

# %%
# Imagenet Data import
home_dir = os.path.expanduser('~') + "/"
datasets_dir = home_dir + "external_drive/"
imagenet_dir = datasets_dir + "imagenet/"

# Get list of training images
train_filenames = []
with open(imagenet_dir + "2012_train_filenames.txt", "r") as file:
    for line in file:
        train_filenames.append(line.strip())

# %%
# Get all class names from filenames, and index them for use in one-hot labeling
classes = set()
for filename in train_filenames:
    classes.add(filename.split("_")[0])
index_to_class = list(classes)
class_to_index = {}
for index, classname in enumerate(index_to_class):
    class_to_index[classname] = index

# %%
# %%timeit
# How long does it take to load a batch?
x_1, y_1 = get_batch(train_filenames, batch_size, image_size, num_classes)

# %%
# %%time
for x in range(10):
    i = randint(0, len(train_filenames))
    filename = train_filenames[i]
    image = read_jpeg(filename)
    #image = crop_resize_image(image, 224)
# Out:
# CPU times: user 92 ms, sys: 4 ms, total: 96 ms
# Wall time: 359 ms

# %%
def crop_resize_image(image, desired_dimension):
    width, height, depth = image.shape
    if width >= height:
        cropped_image = image[int(width / 2) - int(height/2):int(width / 2) + int(height/2),:,:]
    else:
        cropped_image = image[:,int(height / 2) - int(width/2):int(height / 2) + int(width/2),:]
    return cv2.resize(cropped_image, (desired_dimension, desired_dimension))

# Returns a [height, width, depth] image in RGB pixel order
def read_jpeg(filename):
    image = cv2.imread(imagenet_dir + "2012_train/{}".format(filename))
    if image is None:
        print("Failed to read image! This is probably bad")
    # Convert BGR to RGB. 
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # Subtract image means from all of imagenet. I think these are RGB, but might be BGR.....
    image = image - np.array([104, 116, 122])
    image = image / 255.0
    return  image

# Plots an image from either filename or numpy array. 
def show_image(image):
    if isinstance(image, str):
        image = read_jpeg(image)
    fig = plt.figure()
    ax = fig.add_subplot(111, aspect='equal')
    ax.imshow(image)

image_index = 0
# Gets a batch of images from a given list of filenames
def get_batch(filenames, num_images, img_size, num_classes):
    global image_index
    #shuffle(filenames)
    images = []
    classes = []
    if image_index > len(filenames) - 2 * num_images:
        print("Finished epoch, shuffling filenames!")
        shuffle(filenames)
        image_index = 0
    while len(images) < num_images:
        filename = filenames[image_index]
        image = read_jpeg(filename)
        image = crop_resize_image(image, img_size)
        images.append(image)
        classes.append(class_to_index[filename.split("_")[0]])
        image_index += 1
    return np.array(images), dense_to_one_hot(np.array(classes), num_classes)

def dense_to_one_hot(labels_dense, num_classes=10):
    """Convert class labels from scalars to one-hot vectors."""
    num_labels = labels_dense.shape[0]
    index_offset = np.arange(num_labels) * num_classes
    labels_one_hot = np.zeros((num_labels, num_classes))
    labels_one_hot.flat[index_offset + labels_dense.ravel()] = 1
    return labels_one_hot

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.01)
    return tf.Variable(initial)

def bias_variable(shape, value):
    initial = tf.constant(float(value), shape=shape)
    return tf.Variable(initial)

def conv2d(x, W, stride):
    return tf.nn.conv2d(x, W, strides=[1, stride, stride, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

# %%
# Need to implement image resizing!!! (and maybe also various augmentations)
# Bring from 0, 255 to 0, 1
# Subtract mean
# Then, bounding boxes will need re-scaled also..

# %%
# TURN THESE INTO TENSORFLOW VARIABLES SO THEY CAN BE DYNAMICALLY CHANGED

# The width and height of the image
image_size = 224 # Must be divisible by the pooling layers
# Image depth
image_depth = 3
# The batch size
batch_size = 128
test_batch_size = 256
# number of classes
num_classes = 1000

# %%
# Something like Alexnet
sess = tf.InteractiveSession()

# Placeholder for the image size
#image_size_variable = tf.placeholder(tf.float32)

# Batched input
x = tf.placeholder(tf.float32, shape=[None, image_size, image_size, image_depth]) # batch size, image size, image size, image depth
y_ = tf.placeholder(tf.float32, shape=[None, num_classes]) # batch size, num_classes

# First Convolutional Layer
# Variables
W_conv1 = weight_variable([11, 11, image_depth, 96]) # filter size, filter size, input channels (image depth), output channels
b_conv1 = bias_variable([96], 0)
# Layers
h_conv1 = tf.nn.relu(conv2d(x, W_conv1, stride=4) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# Second Convolutional Layer
# Variables
W_conv2 = weight_variable([5, 5, 96, 256])
b_conv2 = bias_variable([256], 1)
# Layers
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2, stride=1) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# Third Convolutional Layer
# Variables
W_conv3 = weight_variable([3, 3, 256, 384])
b_conv3 = bias_variable([384], 0)
# Layers
h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3, stride=1) + b_conv3)

# Fourth Convolutional Layer
# Variables
W_conv4 = weight_variable([3, 3, 384, 384])
b_conv4 = bias_variable([384], 1)
# Layers
h_conv4 = tf.nn.relu(conv2d(h_conv3, W_conv4, stride=1) + b_conv4)

# Fifth Convolutional Layer
# Variables
W_conv5 = weight_variable([3, 3, 384, 256])
b_conv5 = bias_variable([256], 1)
# Layers
h_conv5 = tf.nn.relu(conv2d(h_conv4, W_conv5, stride=1) + b_conv5)
h_pool5 = max_pool_2x2(h_conv5)

# Fully Connected 1
# Weights
W_fc1 = weight_variable([int(image_size/32) * int(image_size/32) * 256, 4096])
b_fc1 = bias_variable([4096], 1)
# Layers
h_pool5_flat = tf.reshape(h_pool5, [-1, int(image_size/32) * int(image_size/32)*256])
h_fc1 = tf.nn.relu(tf.matmul(h_pool5_flat, W_fc1) + b_fc1)

# Fully Connected 2
# Weights
W_fc2 = weight_variable([4096, 4096])
b_fc2 = bias_variable([4096], 1)
# Layers
h_fc2 = tf.nn.relu(tf.matmul(h_fc1, W_fc2) + b_fc2)

# Dropout (fix this and apply to both layers)
keep_prob = tf.placeholder(tf.float32)
#h_fc2_drop = tf.nn.dropout(h_fc2, keep_prob)

# Softmax
# Weights
W_fc3 = weight_variable([4096, num_classes])
b_fc3 = bias_variable([num_classes], 0)
# Layers
y_conv=tf.nn.softmax(tf.matmul(h_fc2, W_fc3) + b_fc3)

# %%
  
#cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))
cross_entropy = -tf.reduce_sum(y_*tf.log(tf.clip_by_value(y_conv,1e-10,1.0)))

learning_rate = tf.placeholder(tf.float32)
train_step = tf.train.MomentumOptimizer(learning_rate, .9).minimize(cross_entropy)
#train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(cross_entropy)
#train_step = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy)


correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
# Make summary of cross entropy loss
ce_summ = tf.scalar_summary("cross entropy", cross_entropy)

# Make a summary of training accuracy
#correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
#accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
accuracy_summary = tf.scalar_summary("accuracy", accuracy)

# Learning rate summary
learning_rate_summary = tf.scalar_summary("learning rate", learning_rate)

# Merge all the summaries and write them out to /tmp/mnist_logs
merged = tf.merge_all_summaries()

# %%
sess.run(tf.initialize_all_variables())
i = 0
save_name = "imagenet_1"
writer = tf.train.SummaryWriter(home_dir + "projects/deep_learning/tensorflow/tmp/mnist_logs/"+save_name, sess.graph_def, flush_secs=10)

# %%
learning_rate_value = .01
dropout = .5

while(True):
    i += 1
    if i%10 == 0:
        
        batch = get_batch(train_filenames, test_batch_size, image_size, num_classes)
        #train_accuracy = accuracy.eval(feed_dict={x:batch[0], y_: batch[1], keep_prob: 1.0})
        #print("step %d, training accuracy %g"%(i, train_accuracy))
        #print(sess.run([cross_entropy], feed_dict={x: batch[0], y_: batch[1], keep_prob: 1})[0])
        summary, accuracy_value = sess.run([merged, accuracy], 
                    feed_dict={x: batch[0], y_: batch[1], keep_prob: 1., learning_rate: learning_rate_value})
        #print(summary)
        writer.add_summary(summary, i)
        print("Accuracy at step %s: %s" % (i, accuracy_value))
    else:
        batch = get_batch(train_filenames, batch_size, image_size, num_classes)
        train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: dropout, learning_rate: learning_rate_value})

#print("test accuracy %g"%accuracy.eval(feed_dict={x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
# Out:
# Accuracy at step 20: 0.0
# Accuracy at step 30: 0.0
# Accuracy at step 40: 0.0
# Accuracy at step 50: 0.0
# Accuracy at step 60: 0.0
# Accuracy at step 70: 0.0
# Accuracy at step 80: 0.0
# Accuracy at step 90: 0.0
# Accuracy at step 100: 0.0
# Accuracy at step 110: 0.0
# Accuracy at step 120: 0.0
# Accuracy at step 130: 0.0
# Accuracy at step 140: 0.0
# Accuracy at step 150: 0.0
# Accuracy at step 160: 0.0
# Accuracy at step 170: 0.0
# Accuracy at step 180: 0.0
# Accuracy at step 190: 0.0
# Accuracy at step 200: 0.0
# Accuracy at step 210: 0.0
# Accuracy at step 220: 0.0
# Accuracy at step 230: 0.0
# Accuracy at step 240: 0.0
# Accuracy at step 250: 0.0
# Accuracy at step 260: 0.0
# Accuracy at step 270: 0.0
# Accuracy at step 280: 0.0
# Accuracy at step 290: 0.0
# Accuracy at step 300: 0.0
# Accuracy at step 310: 0.0
# Accuracy at step 320: 0.0
# Accuracy at step 330: 0.0
# Accuracy at step 340: 0.0
# Accuracy at step 350: 0.0
# Accuracy at step 360: 0.0
# Accuracy at step 370: 0.0
# Accuracy at step 380: 0.0
# Accuracy at step 390: 0.0
# Accuracy at step 400: 0.0
# Accuracy at step 410: 0.0
# Accuracy at step 420: 0.0
# Accuracy at step 430: 0.0
# Accuracy at step 440: 0.0
# Accuracy at step 450: 0.0
# Accuracy at step 460: 0.0
# Accuracy at step 470: 0.0
# Accuracy at step 480: 0.0
# Accuracy at step 490: 0.0
# Accuracy at step 500: 0.0
# Accuracy at step 510: 0.0
# Accuracy at step 520: 0.0
# Accuracy at step 530: 0.0
# Accuracy at step 540: 0.0
# Accuracy at step 550: 0.0
# Accuracy at step 560: 0.0
# Accuracy at step 570: 0.0
# Accuracy at step 580: 0.0
# Accuracy at step 590: 0.0
# Accuracy at step 600: 0.0
# Accuracy at step 610: 0.0
# Accuracy at step 620: 0.0
# Accuracy at step 630: 0.0
# Accuracy at step 640: 0.0
# Accuracy at step 650: 0.0
# Accuracy at step 660: 0.0
# Accuracy at step 670: 0.0
# Accuracy at step 680: 0.0
# Accuracy at step 690: 0.0
# Accuracy at step 700: 0.0
# Accuracy at step 710: 0.0
# Accuracy at step 720: 0.0
# Accuracy at step 730: 0.0
# Accuracy at step 740: 0.0
# Accuracy at step 750: 0.0
# Accuracy at step 760: 0.0
# Accuracy at step 770: 0.0
# Accuracy at step 780: 0.0
# Accuracy at step 790: 0.0
# Accuracy at step 800: 0.0
# Accuracy at step 810: 0.0
# Accuracy at step 820: 0.0
# Accuracy at step 830: 0.0
# Accuracy at step 840: 0.0
# Accuracy at step 850: 0.0
# Accuracy at step 860: 0.0
# Accuracy at step 870: 0.0
# Accuracy at step 880: 0.0
# Accuracy at step 890: 0.0
# Accuracy at step 900: 0.0
# Accuracy at step 910: 0.0
# Accuracy at step 920: 0.0
# Accuracy at step 930: 0.0
# Accuracy at step 940: 0.0
# Accuracy at step 950: 0.0
# Accuracy at step 960: 0.0
# Accuracy at step 970: 0.0
# Accuracy at step 980: 0.0
# Accuracy at step 990: 0.0
# Accuracy at step 1000: 0.0
# Accuracy at step 1010: 0.0
# Accuracy at step 1020: 0.0
# Accuracy at step 1030: 0.0
# Accuracy at step 1040: 0.0
# Accuracy at step 1050: 0.0
# Accuracy at step 1060: 0.0
# Accuracy at step 1070: 0.0
# Accuracy at step 1080: 0.0
# Accuracy at step 1090: 0.0
# Accuracy at step 1100: 0.0
# Accuracy at step 1110: 0.0
# Accuracy at step 1120: 0.0
# Accuracy at step 1130: 0.0
# Accuracy at step 1140: 0.0
# Accuracy at step 1150: 0.0
# Accuracy at step 1160: 0.0
# Accuracy at step 1170: 0.0
# Accuracy at step 1180: 0.0
# Accuracy at step 1190: 0.0
# Accuracy at step 1200: 0.0
# Accuracy at step 1210: 0.0
# Accuracy at step 1220: 0.0
# Accuracy at step 1230: 0.0
# Accuracy at step 1240: 0.0
# Accuracy at step 1250: 0.0
# Accuracy at step 1260: 0.0
# Accuracy at step 1270: 0.0
# Accuracy at step 1280: 0.0
# Accuracy at step 1290: 0.0
# Accuracy at step 1300: 0.0
# Accuracy at step 1310: 0.0
# Accuracy at step 1320: 0.0
# Accuracy at step 1330: 0.0
# Accuracy at step 1340: 0.0
# Accuracy at step 1350: 0.0
# Accuracy at step 1360: 0.0
# Accuracy at step 1370: 0.0
# Accuracy at step 1380: 0.0
# Accuracy at step 1390: 0.0
# Accuracy at step 1400: 0.0
# Accuracy at step 1410: 0.0
# Accuracy at step 1420: 0.0
# Accuracy at step 1430: 0.0
# Accuracy at step 1440: 0.0
# Accuracy at step 1450: 0.0
# Accuracy at step 1460: 0.0
# Accuracy at step 1470: 0.0
# Accuracy at step 1480: 0.0
# Accuracy at step 1490: 0.0
# Accuracy at step 1500: 0.0
# Accuracy at step 1510: 0.0
# Accuracy at step 1520: 0.0
# Accuracy at step 1530: 0.0
# Accuracy at step 1540: 0.0
# Accuracy at step 1550: 0.0
# Accuracy at step 1560: 0.0
# Accuracy at step 1570: 0.0
# Accuracy at step 1580: 0.0
# Accuracy at step 1590: 0.0
# Accuracy at step 1600: 0.0
# Accuracy at step 1610: 0.0
# Accuracy at step 1620: 0.0
# Accuracy at step 1630: 0.0
# Accuracy at step 1640: 0.0
# Accuracy at step 1650: 0.0
# Accuracy at step 1660: 0.0
# Accuracy at step 1670: 0.0
# Accuracy at step 1680: 0.0
# Accuracy at step 1690: 0.0
# Accuracy at step 1700: 0.0
# Accuracy at step 1710: 0.0
# Accuracy at step 1720: 0.0
# Accuracy at step 1730: 0.0
# Accuracy at step 1740: 0.0
# Accuracy at step 1750: 0.0
# Accuracy at step 1760: 0.0
# Accuracy at step 1770: 0.0
# Accuracy at step 1780: 0.0
# Accuracy at step 1790: 0.0
# Accuracy at step 1800: 0.0
# Accuracy at step 1810: 0.0
# Accuracy at step 1820: 0.0
# Accuracy at step 1830: 0.0
# Accuracy at step 1840: 0.0
# Accuracy at step 1850: 0.0
# Accuracy at step 1860: 0.0
# Accuracy at step 1870: 0.0
# Accuracy at step 1880: 0.0
# Accuracy at step 1890: 0.0
# Accuracy at step 1900: 0.0
# Accuracy at step 1910: 0.0
# Accuracy at step 1920: 0.0
# Accuracy at step 1930: 0.0
# Accuracy at step 1940: 0.0
# Accuracy at step 1950: 0.0
# Accuracy at step 1960: 0.0
# Accuracy at step 1970: 0.0
# Accuracy at step 1980: 0.0
# Accuracy at step 1990: 0.0
# Accuracy at step 2000: 0.0
# Accuracy at step 2010: 0.0
# Accuracy at step 2020: 0.0
# Accuracy at step 2030: 0.0
# Accuracy at step 2040: 0.0
# Accuracy at step 2050: 0.0
# Accuracy at step 2060: 0.0
# Accuracy at step 2070: 0.0
# Accuracy at step 2080: 0.0
# Accuracy at step 2090: 0.0
# Accuracy at step 2100: 0.0
# Accuracy at step 2110: 0.0
# Accuracy at step 2120: 0.0
# Accuracy at step 2130: 0.0
# Accuracy at step 2140: 0.0
# Accuracy at step 2150: 0.0
# Accuracy at step 2160: 0.0
# Accuracy at step 2170: 0.0
# Accuracy at step 2180: 0.0
# Accuracy at step 2190: 0.0
# Accuracy at step 2200: 0.0
# Accuracy at step 2210: 0.0
# Accuracy at step 2220: 0.0
# Accuracy at step 2230: 0.0
# Accuracy at step 2240: 0.0
# Accuracy at step 2250: 0.0
# Accuracy at step 2260: 0.0
# Accuracy at step 2270: 0.0
# Accuracy at step 2280: 0.0
# Accuracy at step 2290: 0.0
# Accuracy at step 2300: 0.0
# Accuracy at step 2310: 0.0
# Accuracy at step 2320: 0.0
# Accuracy at step 2330: 0.0
# Accuracy at step 2340: 0.0
# Accuracy at step 2350: 0.0
# Accuracy at step 2360: 0.0
# Accuracy at step 2370: 0.0
# Accuracy at step 2380: 0.0
# Accuracy at step 2390: 0.0
# Accuracy at step 2400: 0.0
# Accuracy at step 2410: 0.0
# Accuracy at step 2420: 0.0
# Accuracy at step 2430: 0.0
# Accuracy at step 2440: 0.0
# Accuracy at step 2450: 0.0
# Accuracy at step 2460: 0.0
# Accuracy at step 2470: 0.0
# Accuracy at step 2480: 0.0
# Accuracy at step 2490: 0.0
# Accuracy at step 2500: 0.0
# Accuracy at step 2510: 0.0
# Accuracy at step 2520: 0.0
# Accuracy at step 2530: 0.0
# Accuracy at step 2540: 0.0
# Accuracy at step 2550: 0.0
# Accuracy at step 2560: 0.0
# Accuracy at step 2570: 0.0
# Accuracy at step 2580: 0.0
# Accuracy at step 2590: 0.0
# Accuracy at step 2600: 0.0
# Accuracy at step 2610: 0.0
# Accuracy at step 2620: 0.0
# Accuracy at step 2630: 0.0
# Accuracy at step 2640: 0.0
# Accuracy at step 2650: 0.0
# Accuracy at step 2660: 0.0
# Accuracy at step 2670: 0.0
# Accuracy at step 2680: 0.0
# Accuracy at step 2690: 0.0
# Accuracy at step 2700: 0.0
# Accuracy at step 2710: 0.0
# Accuracy at step 2720: 0.0
# Accuracy at step 2730: 0.0
# Accuracy at step 2740: 0.0
# Accuracy at step 2750: 0.0
# Accuracy at step 2760: 0.0
# Accuracy at step 2770: 0.0
# Accuracy at step 2780: 0.0
# Accuracy at step 2790: 0.0
# Accuracy at step 2800: 0.0
# Accuracy at step 2810: 0.0
# Accuracy at step 2820: 0.0
# Accuracy at step 2830: 0.0
# Accuracy at step 2840: 0.0
# Accuracy at step 2850: 0.0
# Accuracy at step 2860: 0.0
# Accuracy at step 2870: 0.0
# Accuracy at step 2880: 0.0
# Accuracy at step 2890: 0.0
# Accuracy at step 2900: 0.0
# Accuracy at step 2910: 0.0
# Accuracy at step 2920: 0.0
# Accuracy at step 2930: 0.0
# Accuracy at step 2940: 0.0
# Accuracy at step 2950: 0.0
# Accuracy at step 2960: 0.0
# Accuracy at step 2970: 0.0
# Accuracy at step 2980: 0.0
# Accuracy at step 2990: 0.0
# Accuracy at step 3000: 0.0
# Accuracy at step 3010: 0.0
# Accuracy at step 3020: 0.0
# Accuracy at step 3030: 0.0
# Accuracy at step 3040: 0.0
# Accuracy at step 3050: 0.0
# Accuracy at step 3060: 0.0
# Accuracy at step 3070: 0.0
# Accuracy at step 3080: 0.0
# Accuracy at step 3090: 0.0
# Accuracy at step 3100: 0.0
# Accuracy at step 3110: 0.0
# Accuracy at step 3120: 0.0
# Accuracy at step 3130: 0.0
# Accuracy at step 3140: 0.0
# Accuracy at step 3150: 0.0
# Accuracy at step 3160: 0.0
# Accuracy at step 3170: 0.0
# Accuracy at step 3180: 0.0
# Accuracy at step 3190: 0.0
# Accuracy at step 3200: 0.0
# Accuracy at step 3210: 0.0
# Accuracy at step 3220: 0.0
# Accuracy at step 3230: 0.0
# Accuracy at step 3240: 0.0
# Accuracy at step 3250: 0.0
# Accuracy at step 3260: 0.0
# Accuracy at step 3270: 0.0
# Accuracy at step 3280: 0.0
# Accuracy at step 3290: 0.0
# Accuracy at step 3300: 0.0
# Accuracy at step 3310: 0.0
# Accuracy at step 3320: 0.0
# Accuracy at step 3330: 0.0
# Accuracy at step 3340: 0.0
# Accuracy at step 3350: 0.0
# Accuracy at step 3360: 0.0
# Accuracy at step 3370: 0.0
# Accuracy at step 3380: 0.0
# Accuracy at step 3390: 0.0
# Accuracy at step 3400: 0.0
# Accuracy at step 3410: 0.0
# Accuracy at step 3420: 0.0
# Accuracy at step 3430: 0.0
# Accuracy at step 3440: 0.0
# Accuracy at step 3450: 0.0
# Accuracy at step 3460: 0.0
# Accuracy at step 3470: 0.0
# Accuracy at step 3480: 0.0
# Accuracy at step 3490: 0.0
# Accuracy at step 3500: 0.0
# Accuracy at step 3510: 0.0
# Accuracy at step 3520: 0.0
# Accuracy at step 3530: 0.0
# Accuracy at step 3540: 0.0
# Accuracy at step 3550: 0.0
# Accuracy at step 3560: 0.0
# Accuracy at step 3570: 0.0
# Accuracy at step 3580: 0.0
# Accuracy at step 3590: 0.0
# Accuracy at step 3600: 0.0
# Accuracy at step 3610: 0.0
# Accuracy at step 3620: 0.0
# Accuracy at step 3630: 0.0
# Accuracy at step 3640: 0.0
# Accuracy at step 3650: 0.0
# Accuracy at step 3660: 0.0
# Accuracy at step 3670: 0.0
# Accuracy at step 3680: 0.0
# Accuracy at step 3690: 0.0
# Accuracy at step 3700: 0.0
# Accuracy at step 3710: 0.0
# Accuracy at step 3720: 0.0
# Accuracy at step 3730: 0.0
# Accuracy at step 3740: 0.0
# Accuracy at step 3750: 0.0
# Accuracy at step 3760: 0.0
# Accuracy at step 3770: 0.0
# Accuracy at step 3780: 0.0
# Accuracy at step 3790: 0.0
# Accuracy at step 3800: 0.0
# Accuracy at step 3810: 0.0
# Accuracy at step 3820: 0.0
# Accuracy at step 3830: 0.0
# Accuracy at step 3840: 0.0
# Accuracy at step 3850: 0.0
# Accuracy at step 3860: 0.0
# Accuracy at step 3870: 0.0
# Accuracy at step 3880: 0.0
# Accuracy at step 3890: 0.0
# Accuracy at step 3900: 0.0
# Accuracy at step 3910: 0.0
# Accuracy at step 3920: 0.0
# Accuracy at step 3930: 0.0
# Accuracy at step 3940: 0.0
# Accuracy at step 3950: 0.0
# Accuracy at step 3960: 0.0
# Accuracy at step 3970: 0.0
# Accuracy at step 3980: 0.0
# Accuracy at step 3990: 0.0
# Accuracy at step 4000: 0.0
# Accuracy at step 4010: 0.0
# Accuracy at step 4020: 0.0
# Accuracy at step 4030: 0.0
# Accuracy at step 4040: 0.0
# Accuracy at step 4050: 0.0
# Accuracy at step 4060: 0.0
# Accuracy at step 4070: 0.0
# Accuracy at step 4080: 1.0
# Accuracy at step 4090: 0.0
# Accuracy at step 4100: 0.0
# Accuracy at step 4110: 0.0
# Accuracy at step 4120: 0.0
# Accuracy at step 4130: 0.0
# Accuracy at step 4140: 0.0
# Accuracy at step 4150: 0.0
# Accuracy at step 4160: 0.0
# Accuracy at step 4170: 0.0
# Accuracy at step 4180: 0.0
# Accuracy at step 4190: 0.0
# Accuracy at step 4200: 0.0
# Accuracy at step 4210: 0.0
# Accuracy at step 4220: 0.0
# Accuracy at step 4230: 0.0
# Accuracy at step 4240: 0.0
# Accuracy at step 4250: 0.0
# Accuracy at step 4260: 0.0
# Accuracy at step 4270: 0.0
# Accuracy at step 4280: 0.0
# Accuracy at step 4290: 0.0
# Accuracy at step 4300: 0.0
# Accuracy at step 4310: 0.0
# Accuracy at step 4320: 0.0
# Accuracy at step 4330: 0.0
# Accuracy at step 4340: 0.0
# Accuracy at step 4350: 0.0
# Accuracy at step 4360: 0.0
# Accuracy at step 4370: 0.0
# Accuracy at step 4380: 0.0
# Accuracy at step 4390: 0.0
# Accuracy at step 4400: 0.0
# Accuracy at step 4410: 0.0
# Accuracy at step 4420: 0.0
# Accuracy at step 4430: 0.0
# Accuracy at step 4440: 0.0
# Accuracy at step 4450: 0.0
# Accuracy at step 4460: 0.0
# Accuracy at step 4470: 0.0
# Accuracy at step 4480: 0.0
# Accuracy at step 4490: 0.0
# Accuracy at step 4500: 0.0
# Accuracy at step 4510: 0.0
# Accuracy at step 4520: 0.0
# Accuracy at step 4530: 0.0
# Accuracy at step 4540: 0.0
# Accuracy at step 4550: 0.0
# Accuracy at step 4560: 0.0
# Accuracy at step 4570: 0.0
# Accuracy at step 4580: 0.0
# Accuracy at step 4590: 0.0
# Accuracy at step 4600: 0.0
# Accuracy at step 4610: 0.0
# Accuracy at step 4620: 0.0
# Accuracy at step 4630: 0.0
# Accuracy at step 4640: 0.0
# Accuracy at step 4650: 0.0
# Accuracy at step 4660: 0.0
# Accuracy at step 4670: 0.0
# Accuracy at step 4680: 0.0
# Accuracy at step 4690: 0.0
# Accuracy at step 4700: 0.0
# Accuracy at step 4710: 0.0
# Accuracy at step 4720: 0.0
# Accuracy at step 4730: 0.0
# Accuracy at step 4740: 0.0
# Accuracy at step 4750: 0.0
# Accuracy at step 4760: 0.0
# Accuracy at step 4770: 0.0
# Accuracy at step 4780: 0.0
# Accuracy at step 4790: 0.0
# Accuracy at step 4800: 0.0
# Accuracy at step 4810: 0.0
# Accuracy at step 4820: 0.0
# Accuracy at step 4830: 0.0
# Accuracy at step 4840: 0.0
# Accuracy at step 4850: 0.0
# Accuracy at step 4860: 0.0
# Accuracy at step 4870: 0.0
# Accuracy at step 4880: 0.0
# Accuracy at step 4890: 0.0
# Accuracy at step 4900: 0.0
# Accuracy at step 4910: 0.0
# Accuracy at step 4920: 0.0
# Accuracy at step 4930: 0.0
# Accuracy at step 4940: 0.0
# Accuracy at step 4950: 0.0
# Accuracy at step 4960: 0.0
# Accuracy at step 4970: 0.0
# Accuracy at step 4980: 0.0
# Accuracy at step 4990: 0.0
# Accuracy at step 5000: 0.0
# Accuracy at step 5010: 0.0
# Accuracy at step 5020: 0.0
# Accuracy at step 5030: 0.0
# Accuracy at step 5040: 0.0
# Accuracy at step 5050: 0.0
# Accuracy at step 5060: 0.0
# Accuracy at step 5070: 0.0
# Accuracy at step 5080: 0.0
# Accuracy at step 5090: 0.0
# Accuracy at step 5100: 0.0
# Accuracy at step 5110: 0.0
# Accuracy at step 5120: 0.0
# Accuracy at step 5130: 0.0
# Accuracy at step 5140: 0.0
# Accuracy at step 5150: 0.0
# Accuracy at step 5160: 0.0
# Accuracy at step 5170: 0.0
# Accuracy at step 5180: 0.0
# Accuracy at step 5190: 0.0
# Accuracy at step 5200: 0.0
# Accuracy at step 5210: 0.0
# Accuracy at step 5220: 0.0
# Accuracy at step 5230: 0.0
# Accuracy at step 5240: 0.0
# Accuracy at step 5250: 0.0
# Accuracy at step 5260: 0.0
# Accuracy at step 5270: 0.0
# Accuracy at step 5280: 0.0
# Accuracy at step 5290: 0.0
# Accuracy at step 5300: 0.0
# Accuracy at step 5310: 0.0
# Accuracy at step 5320: 0.0
# Accuracy at step 5330: 0.0
# Accuracy at step 5340: 0.0
# Accuracy at step 5350: 0.0
# Accuracy at step 5360: 0.0
# Accuracy at step 5370: 0.0
# Accuracy at step 5380: 0.0
# Accuracy at step 5390: 0.0
# Accuracy at step 5400: 0.0
# Accuracy at step 5410: 0.0
# Accuracy at step 5420: 0.0
# Accuracy at step 5430: 0.0
# Accuracy at step 5440: 0.0
# Accuracy at step 5450: 0.0
# Accuracy at step 5460: 0.0
# Accuracy at step 5470: 0.0
# Accuracy at step 5480: 0.0
# Accuracy at step 5490: 0.0
# Accuracy at step 5500: 0.0
# Accuracy at step 5510: 0.0
# Accuracy at step 5520: 0.0
# Accuracy at step 5530: 0.0
# Accuracy at step 5540: 0.0
# Accuracy at step 5550: 0.0
# Accuracy at step 5560: 0.0
# Accuracy at step 5570: 0.0
# Accuracy at step 5580: 0.0
# Accuracy at step 5590: 0.0
# Accuracy at step 5600: 0.0
# Accuracy at step 5610: 0.0
# Accuracy at step 5620: 0.0
# Accuracy at step 5630: 0.0
# Accuracy at step 5640: 0.0
# Accuracy at step 5650: 0.0
# Accuracy at step 5660: 0.0
# Accuracy at step 5670: 0.0
# Accuracy at step 5680: 0.0
# Accuracy at step 5690: 0.0
# Accuracy at step 5700: 0.0
# Accuracy at step 5710: 0.0
# Accuracy at step 5720: 0.0
# Accuracy at step 5730: 0.0
# Accuracy at step 5740: 0.0
# Accuracy at step 5750: 0.0
# Accuracy at step 5760: 0.0
# Accuracy at step 5770: 0.0
# Accuracy at step 5780: 0.0
# Accuracy at step 5790: 0.0
# Accuracy at step 5800: 0.0
# Accuracy at step 5810: 0.0
# Accuracy at step 5820: 0.0
# Accuracy at step 5830: 0.0
# Accuracy at step 5840: 0.0
# Accuracy at step 5850: 0.0
# Accuracy at step 5860: 0.0
# Accuracy at step 5870: 0.0
# Accuracy at step 5880: 0.0
# Accuracy at step 5890: 0.0
# Accuracy at step 5900: 0.0
# Accuracy at step 5910: 0.0
# Accuracy at step 5920: 0.0
# Accuracy at step 5930: 0.0
# Accuracy at step 5940: 0.0
# Accuracy at step 5950: 0.0
# Accuracy at step 5960: 0.0
# Accuracy at step 5970: 0.0
# Accuracy at step 5980: 0.0
# Accuracy at step 5990: 0.0
# Accuracy at step 6000: 0.0
# Accuracy at step 6010: 0.0
# Accuracy at step 6020: 0.0
# Accuracy at step 6030: 0.0
# Accuracy at step 6040: 0.0
# Accuracy at step 6050: 0.0
# Accuracy at step 6060: 0.0
# Accuracy at step 6070: 0.0
# Accuracy at step 6080: 0.0
# Accuracy at step 6090: 0.0
# Accuracy at step 6100: 0.0
# Accuracy at step 6110: 0.0
# Accuracy at step 6120: 0.0
# Accuracy at step 6130: 0.0
# Accuracy at step 6140: 0.0
# Accuracy at step 6150: 0.0
# Accuracy at step 6160: 0.0
# Accuracy at step 6170: 0.0
# Accuracy at step 6180: 0.0
# Accuracy at step 6190: 0.0
# Accuracy at step 6200: 0.0
# Accuracy at step 6210: 0.0
# Accuracy at step 6220: 0.0
# Accuracy at step 6230: 0.0
# Accuracy at step 6240: 0.0
# Accuracy at step 6250: 0.0
# Accuracy at step 6260: 0.0
# Accuracy at step 6270: 0.0
# Accuracy at step 6280: 0.0
# Accuracy at step 6290: 0.0
# Accuracy at step 6300: 0.0
# Accuracy at step 6310: 0.0
# Accuracy at step 6320: 0.0
# Accuracy at step 6330: 0.0
# Accuracy at step 6340: 0.0
# Accuracy at step 6350: 0.0
# Accuracy at step 6360: 0.0
# Accuracy at step 6370: 0.0
# Accuracy at step 6380: 0.0
# Accuracy at step 6390: 0.0
# Accuracy at step 6400: 0.0
# Accuracy at step 6410: 0.0
# Accuracy at step 6420: 0.0
# Accuracy at step 6430: 0.0
# Accuracy at step 6440: 0.0
# Accuracy at step 6450: 0.0
# Accuracy at step 6460: 0.0
# Accuracy at step 6470: 0.0
# Accuracy at step 6480: 0.0
# Accuracy at step 6490: 0.0
# Accuracy at step 6500: 0.0
# Accuracy at step 6510: 0.0
# Accuracy at step 6520: 0.0
# Accuracy at step 6530: 0.0
# Accuracy at step 6540: 0.0
# Accuracy at step 6550: 0.0
# Accuracy at step 6560: 0.0
# Accuracy at step 6570: 0.0
# Accuracy at step 6580: 0.0
# Accuracy at step 6590: 0.0
# Accuracy at step 6600: 0.0
# Accuracy at step 6610: 0.0
# Accuracy at step 6620: 0.0
# Accuracy at step 6630: 0.0
# Accuracy at step 6640: 0.0
# Accuracy at step 6650: 0.0
# Accuracy at step 6660: 0.0
# Accuracy at step 6670: 0.0
# Accuracy at step 6680: 0.0
# Accuracy at step 6690: 0.0
# Accuracy at step 6700: 0.0
# Accuracy at step 6710: 0.0
# Accuracy at step 6720: 0.0
# Accuracy at step 6730: 0.0
# Accuracy at step 6740: 0.0
# Accuracy at step 6750: 0.0
# Accuracy at step 6760: 0.0
# Accuracy at step 6770: 0.0
# Accuracy at step 6780: 0.0
# Accuracy at step 6790: 0.0
# Accuracy at step 6800: 0.0
# Accuracy at step 6810: 0.0
# Accuracy at step 6820: 0.0
# Accuracy at step 6830: 0.0
# Accuracy at step 6840: 0.0
# Accuracy at step 6850: 0.0
# Accuracy at step 6860: 0.0
# Accuracy at step 6870: 0.0
# Accuracy at step 6880: 0.0
# Accuracy at step 6890: 0.0
# Accuracy at step 6900: 0.0
# Accuracy at step 6910: 0.0
# Accuracy at step 6920: 0.0
# Accuracy at step 6930: 0.0
# Accuracy at step 6940: 0.0
# Accuracy at step 6950: 0.0
# Accuracy at step 6960: 0.0
# Accuracy at step 6970: 0.0
# Accuracy at step 6980: 0.0
# Accuracy at step 6990: 0.0
# Accuracy at step 7000: 0.0
# Accuracy at step 7010: 0.0
# Accuracy at step 7020: 0.0
# Accuracy at step 7030: 0.0
# Accuracy at step 7040: 0.0
# Accuracy at step 7050: 0.0
# Accuracy at step 7060: 0.0
# Accuracy at step 7070: 0.0
# Accuracy at step 7080: 0.0
# Accuracy at step 7090: 0.0
# Accuracy at step 7100: 0.0
# Accuracy at step 7110: 0.0
# Accuracy at step 7120: 0.0
# Accuracy at step 7130: 0.0
# Accuracy at step 7140: 0.0
# Accuracy at step 7150: 0.0
# Accuracy at step 7160: 0.0
# Accuracy at step 7170: 0.0
# Accuracy at step 7180: 0.0
# Accuracy at step 7190: 0.0
# Accuracy at step 7200: 0.0
# Accuracy at step 7210: 0.0
# Accuracy at step 7220: 0.0
# Accuracy at step 7230: 0.0
# Accuracy at step 7240: 0.0
# Accuracy at step 7250: 0.0
# Accuracy at step 7260: 0.0
# Accuracy at step 7270: 0.0
# Accuracy at step 7280: 0.0
# Accuracy at step 7290: 0.0
# Accuracy at step 7300: 0.0
# Accuracy at step 7310: 0.0
# Accuracy at step 7320: 0.0
# Accuracy at step 7330: 0.0
# Accuracy at step 7340: 0.0
# Accuracy at step 7350: 0.0
# Accuracy at step 7360: 0.0
# Accuracy at step 7370: 0.0
# Accuracy at step 7380: 0.0
# Accuracy at step 7390: 0.0
# Accuracy at step 7400: 0.0
# Accuracy at step 7410: 0.0
# Accuracy at step 7420: 0.0
# Accuracy at step 7430: 0.0
# Accuracy at step 7440: 0.0
# Accuracy at step 7450: 0.0
# Accuracy at step 7460: 0.0
# Accuracy at step 7470: 0.0
# Accuracy at step 7480: 0.0
# Accuracy at step 7490: 0.0
# Accuracy at step 7500: 0.0
# Accuracy at step 7510: 0.0
# Accuracy at step 7520: 0.0
# Accuracy at step 7530: 0.0
# Accuracy at step 7540: 0.0
# Accuracy at step 7550: 0.0
# Accuracy at step 7560: 0.0
# Accuracy at step 7570: 0.0
# Accuracy at step 7580: 0.0
# Accuracy at step 7590: 0.0
# Accuracy at step 7600: 0.0
# Accuracy at step 7610: 0.0
# Accuracy at step 7620: 0.0
# Accuracy at step 7630: 0.0
# Accuracy at step 7640: 0.0
# Accuracy at step 7650: 0.0
# Accuracy at step 7660: 0.0
# Accuracy at step 7670: 0.0
# Accuracy at step 7680: 0.0
# Accuracy at step 7690: 0.0
# Accuracy at step 7700: 0.0
# Accuracy at step 7710: 0.0
# Accuracy at step 7720: 0.0
# Accuracy at step 7730: 0.0
# Accuracy at step 7740: 0.0
# Accuracy at step 7750: 0.0
# Accuracy at step 7760: 0.0
# Accuracy at step 7770: 0.0
# Accuracy at step 7780: 0.0
# Accuracy at step 7790: 0.0
# Accuracy at step 7800: 0.0
# Accuracy at step 7810: 0.0
# Accuracy at step 7820: 0.0
# Accuracy at step 7830: 0.0
# Accuracy at step 7840: 0.0
# Accuracy at step 7850: 0.0
# Accuracy at step 7860: 0.0
# Accuracy at step 7870: 0.0
# Accuracy at step 7880: 0.0
# Accuracy at step 7890: 0.0
# Accuracy at step 7900: 0.0
# Accuracy at step 7910: 0.0
# Accuracy at step 7920: 0.0
# Accuracy at step 7930: 0.0
# Accuracy at step 7940: 0.0
# Accuracy at step 7950: 0.0
# Accuracy at step 7960: 0.0
# Accuracy at step 7970: 0.0
# Accuracy at step 7980: 0.0
# Accuracy at step 7990: 0.0
# Accuracy at step 8000: 0.0
# Accuracy at step 8010: 0.0
# Accuracy at step 8020: 0.0
# Accuracy at step 8030: 0.0
# Accuracy at step 8040: 0.0
# Accuracy at step 8050: 0.0
# Accuracy at step 8060: 0.0
# Accuracy at step 8070: 0.0
# Accuracy at step 8080: 0.0
# Accuracy at step 8090: 0.0
# Accuracy at step 8100: 0.0
# Accuracy at step 8110: 0.0
# Accuracy at step 8120: 0.0
# Accuracy at step 8130: 0.0
# Accuracy at step 8140: 0.0
# Accuracy at step 8150: 0.0
# Accuracy at step 8160: 0.0
# Accuracy at step 8170: 0.0
# Accuracy at step 8180: 0.0
# Accuracy at step 8190: 0.0
# Accuracy at step 8200: 0.0
# Accuracy at step 8210: 0.0
# Accuracy at step 8220: 0.0
# Accuracy at step 8230: 0.0
# Accuracy at step 8240: 0.0
# Accuracy at step 8250: 0.0
# Accuracy at step 8260: 0.0
# Accuracy at step 8270: 0.0
# Accuracy at step 8280: 0.0
# Accuracy at step 8290: 0.0
# Accuracy at step 8300: 0.0
# Accuracy at step 8310: 0.0
# Accuracy at step 8320: 0.0
# Accuracy at step 8330: 0.0
# Accuracy at step 8340: 0.0
# Accuracy at step 8350: 0.0
# Accuracy at step 8360: 0.0
# Accuracy at step 8370: 0.0
# Accuracy at step 8380: 0.0
# Accuracy at step 8390: 0.0
# Accuracy at step 8400: 0.0
# Accuracy at step 8410: 0.0
# Accuracy at step 8420: 0.0
# Accuracy at step 8430: 0.0
# Accuracy at step 8440: 0.0
# Accuracy at step 8450: 0.0
# Accuracy at step 8460: 0.0
# Accuracy at step 8470: 0.0
# Accuracy at step 8480: 0.0
# Accuracy at step 8490: 0.0
# Accuracy at step 8500: 0.0
# Accuracy at step 8510: 0.0
# Accuracy at step 8520: 0.0
# Accuracy at step 8530: 0.0
# Accuracy at step 8540: 0.0
# Accuracy at step 8550: 0.0
# Accuracy at step 8560: 0.0
# Accuracy at step 8570: 0.0
# Accuracy at step 8580: 0.0
# Accuracy at step 8590: 0.0
# Accuracy at step 8600: 0.0
# Accuracy at step 8610: 0.0
# Accuracy at step 8620: 0.0
# Accuracy at step 8630: 0.0
# Accuracy at step 8640: 0.0
# Accuracy at step 8650: 0.0
# Accuracy at step 8660: 0.0
# Accuracy at step 8670: 0.0
# Accuracy at step 8680: 0.0
# Accuracy at step 8690: 0.0
# Accuracy at step 8700: 0.0
# Accuracy at step 8710: 0.0
# Accuracy at step 8720: 0.0
# Accuracy at step 8730: 0.0
# Accuracy at step 8740: 0.0
# Accuracy at step 8750: 0.0
# Accuracy at step 8760: 0.0
# Accuracy at step 8770: 0.0
# Accuracy at step 8780: 0.0
# Accuracy at step 8790: 0.0
# Accuracy at step 8800: 0.0
# Accuracy at step 8810: 0.0
# Accuracy at step 8820: 0.0
# Accuracy at step 8830: 0.0
# Accuracy at step 8840: 0.0
# Accuracy at step 8850: 0.0
# Accuracy at step 8860: 0.0
# Accuracy at step 8870: 0.0
# Accuracy at step 8880: 0.0
# Accuracy at step 8890: 0.0
# Accuracy at step 8900: 0.0
# Accuracy at step 8910: 0.0
# Accuracy at step 8920: 0.0
# Accuracy at step 8930: 0.0
# Accuracy at step 8940: 0.0
# Accuracy at step 8950: 0.0
# Accuracy at step 8960: 0.0
# Accuracy at step 8970: 0.0
# Accuracy at step 8980: 0.0
# Accuracy at step 8990: 0.0
# Accuracy at step 9000: 0.0
# Accuracy at step 9010: 0.0
# Accuracy at step 9020: 0.0
# Accuracy at step 9030: 0.0
# Accuracy at step 9040: 0.0
# Accuracy at step 9050: 0.0
# Accuracy at step 9060: 0.0
# Accuracy at step 9070: 0.0
# Accuracy at step 9080: 0.0
# Accuracy at step 9090: 0.0
# Accuracy at step 9100: 0.0
# Accuracy at step 9110: 0.0
# Accuracy at step 9120: 0.0
# Accuracy at step 9130: 0.0
# Accuracy at step 9140: 0.0
# Accuracy at step 9150: 0.0
# Accuracy at step 9160: 0.0
# Accuracy at step 9170: 0.0
# Accuracy at step 9180: 0.0
# Accuracy at step 9190: 0.0
# Accuracy at step 9200: 0.0
# Accuracy at step 9210: 0.0
# Accuracy at step 9220: 0.0
# Accuracy at step 9230: 0.0
# Accuracy at step 9240: 0.0
# Accuracy at step 9250: 0.0
# Accuracy at step 9260: 0.0
# Accuracy at step 9270: 0.0
# Accuracy at step 9280: 0.0
# Accuracy at step 9290: 0.0
# Accuracy at step 9300: 0.0
# Accuracy at step 9310: 0.0
# Accuracy at step 9320: 0.0
# Accuracy at step 9330: 0.0
# Accuracy at step 9340: 0.0
# Accuracy at step 9350: 0.0
# Accuracy at step 9360: 0.0
# Accuracy at step 9370: 0.0
# Accuracy at step 9380: 0.0
# Accuracy at step 9390: 0.0
# Accuracy at step 9400: 0.0
# Accuracy at step 9410: 0.0
# Accuracy at step 9420: 0.0
# Accuracy at step 9430: 0.0
# Accuracy at step 9440: 0.0
# Accuracy at step 9450: 0.0
# Accuracy at step 9460: 0.0
# Accuracy at step 9470: 0.0
# Accuracy at step 9480: 0.0
# Accuracy at step 9490: 0.0
# Accuracy at step 9500: 0.0
# Accuracy at step 9510: 0.0
# Accuracy at step 9520: 0.0
# Accuracy at step 9530: 0.0
# Accuracy at step 9540: 0.0
# Accuracy at step 9550: 0.0
# Accuracy at step 9560: 0.0
# Accuracy at step 9570: 0.0
# Accuracy at step 9580: 0.0
# Accuracy at step 9590: 0.0
# Accuracy at step 9600: 0.0
# Accuracy at step 9610: 0.0
# Accuracy at step 9620: 0.0
# Accuracy at step 9630: 0.0
# Accuracy at step 9640: 0.0
# Accuracy at step 9650: 0.0
# Accuracy at step 9660: 0.0
# Accuracy at step 9670: 0.0
# Accuracy at step 9680: 0.0
# Accuracy at step 9690: 0.0
# Accuracy at step 9700: 0.0
# Accuracy at step 9710: 0.0
# Accuracy at step 9720: 0.0
# Accuracy at step 9730: 0.0
# Accuracy at step 9740: 0.0
# Accuracy at step 9750: 0.0
# Accuracy at step 9760: 0.0
# Accuracy at step 9770: 0.0
# Accuracy at step 9780: 0.0
# Accuracy at step 9790: 0.0
# Accuracy at step 9800: 0.0
# Accuracy at step 9810: 0.0
# Accuracy at step 9820: 0.0
# Accuracy at step 9830: 0.0
# Accuracy at step 9840: 0.0
# Accuracy at step 9850: 0.0
# Accuracy at step 9860: 0.0
# Accuracy at step 9870: 0.0
# Accuracy at step 9880: 0.0
# Accuracy at step 9890: 0.0
# Accuracy at step 9900: 0.0
# Accuracy at step 9910: 0.0
# Accuracy at step 9920: 0.0
# Accuracy at step 9930: 0.0
# Accuracy at step 9940: 0.0
# Accuracy at step 9950: 0.0
# Accuracy at step 9960: 0.0
# Accuracy at step 9970: 0.0
# Accuracy at step 9980: 0.0
# Accuracy at step 9990: 0.0
# Accuracy at step 10000: 0.0
# Accuracy at step 10010: 0.0
# Accuracy at step 10020: 0.0
# Accuracy at step 10030: 0.0
# Accuracy at step 10040: 0.0
# Accuracy at step 10050: 0.0
# Accuracy at step 10060: 0.0
# Accuracy at step 10070: 0.0
# Accuracy at step 10080: 0.0
# Accuracy at step 10090: 0.0
# Accuracy at step 10100: 0.0
# Accuracy at step 10110: 0.0
# Accuracy at step 10120: 0.0
# Accuracy at step 10130: 0.0
# Accuracy at step 10140: 0.0
# Accuracy at step 10150: 0.0
# Accuracy at step 10160: 0.0
# Accuracy at step 10170: 0.0
# Accuracy at step 10180: 0.0
# Accuracy at step 10190: 0.0
# Accuracy at step 10200: 0.0
# Accuracy at step 10210: 0.0
# Accuracy at step 10220: 0.0
# Accuracy at step 10230: 0.0
# Accuracy at step 10240: 0.0
# Accuracy at step 10250: 0.0
# Accuracy at step 10260: 0.0
# Accuracy at step 10270: 0.0
# Accuracy at step 10280: 0.0
# Accuracy at step 10290: 0.0
# Accuracy at step 10300: 0.0
# Accuracy at step 10310: 0.0
# Accuracy at step 10320: 0.0
# Accuracy at step 10330: 0.0
# Accuracy at step 10340: 0.0
# Accuracy at step 10350: 0.0
# Accuracy at step 10360: 0.0
# Accuracy at step 10370: 0.0
# Accuracy at step 10380: 0.0
# Accuracy at step 10390: 0.0
# Accuracy at step 10400: 0.0
# Accuracy at step 10410: 0.0
# Accuracy at step 10420: 0.0
# Accuracy at step 10430: 0.0
# Accuracy at step 10440: 0.0
# Accuracy at step 10450: 0.0
# Accuracy at step 10460: 0.0
# Accuracy at step 10470: 0.0
# Accuracy at step 10480: 0.0
# Accuracy at step 10490: 0.0
# Accuracy at step 10500: 0.0
# Accuracy at step 10510: 0.0
# Accuracy at step 10520: 0.0
# Accuracy at step 10530: 0.0
# Accuracy at step 10540: 0.0
# Accuracy at step 10550: 0.0
# Accuracy at step 10560: 0.0
# Accuracy at step 10570: 0.0
# Accuracy at step 10580: 0.0
# Accuracy at step 10590: 0.0
# Accuracy at step 10600: 0.0
# Accuracy at step 10610: 0.0
# Accuracy at step 10620: 0.0
# Accuracy at step 10630: 0.0
# Accuracy at step 10640: 0.0
# Accuracy at step 10650: 0.0
# Accuracy at step 10660: 0.0
# Accuracy at step 10670: 0.0
# Accuracy at step 10680: 0.0
# Accuracy at step 10690: 0.0
# Accuracy at step 10700: 0.0
# Accuracy at step 10710: 0.0
# Accuracy at step 10720: 0.0
# Accuracy at step 10730: 0.0
# Accuracy at step 10740: 0.0
# Accuracy at step 10750: 0.0
# Accuracy at step 10760: 0.0
# Accuracy at step 10770: 0.0
# Accuracy at step 10780: 0.0
# Accuracy at step 10790: 0.0
# Accuracy at step 10800: 0.0
# Accuracy at step 10810: 0.0
# Accuracy at step 10820: 0.0
# Accuracy at step 10830: 0.0
# Accuracy at step 10840: 0.0
# Accuracy at step 10850: 0.0
# Accuracy at step 10860: 0.0
# Accuracy at step 10870: 0.0
# Accuracy at step 10880: 0.0
# Accuracy at step 10890: 0.0
# Accuracy at step 10900: 0.0
# Accuracy at step 10910: 0.0
# Accuracy at step 10920: 0.0
# Accuracy at step 10930: 0.0
# Accuracy at step 10940: 0.0
# Accuracy at step 10950: 0.0
# Accuracy at step 10960: 0.0
# Accuracy at step 10970: 0.0
# Accuracy at step 10980: 0.0
# Accuracy at step 10990: 0.0
# Accuracy at step 11000: 0.0
# Accuracy at step 11010: 0.0
# Accuracy at step 11020: 0.0
# Accuracy at step 11030: 0.0
# Accuracy at step 11040: 0.0
# Accuracy at step 11050: 0.0
# Accuracy at step 11060: 0.0
# Accuracy at step 11070: 0.0
# Accuracy at step 11080: 0.0
# Accuracy at step 11090: 0.0
# Accuracy at step 11100: 0.0
# Accuracy at step 11110: 0.0
# Accuracy at step 11120: 0.0
# Accuracy at step 11130: 0.0
# Accuracy at step 11140: 0.0
# Accuracy at step 11150: 0.0
# Accuracy at step 11160: 0.0
# Accuracy at step 11170: 0.0
# Accuracy at step 11180: 0.0
# Accuracy at step 11190: 0.0
# Accuracy at step 11200: 0.0
# Accuracy at step 11210: 0.0
# Accuracy at step 11220: 0.0
# Accuracy at step 11230: 0.0
# Accuracy at step 11240: 0.0
# Accuracy at step 11250: 0.0
# Accuracy at step 11260: 0.0
# Accuracy at step 11270: 0.0
# Accuracy at step 11280: 0.0
# Accuracy at step 11290: 0.0
# Accuracy at step 11300: 0.0
# Accuracy at step 11310: 0.0
# Accuracy at step 11320: 0.0
# Accuracy at step 11330: 0.0
# Accuracy at step 11340: 0.0
# Accuracy at step 11350: 0.0
# Accuracy at step 11360: 0.0
# Accuracy at step 11370: 0.0
# Accuracy at step 11380: 0.0
# Accuracy at step 11390: 0.0
# Accuracy at step 11400: 0.0
# Accuracy at step 11410: 0.0
# Accuracy at step 11420: 0.0
# Accuracy at step 11430: 0.0
# Accuracy at step 11440: 0.0
# Accuracy at step 11450: 0.0
# Accuracy at step 11460: 0.0
# Accuracy at step 11470: 0.0
# Accuracy at step 11480: 0.0
# Accuracy at step 11490: 0.0
# Accuracy at step 11500: 0.0
# Accuracy at step 11510: 0.0
# Accuracy at step 11520: 0.0
# Accuracy at step 11530: 0.0
# Accuracy at step 11540: 0.0
# Accuracy at step 11550: 0.0
# Accuracy at step 11560: 0.0
# Accuracy at step 11570: 0.0
# Accuracy at step 11580: 0.0
# Accuracy at step 11590: 0.0
# Accuracy at step 11600: 0.0
# Accuracy at step 11610: 0.0
# Accuracy at step 11620: 0.0
# Accuracy at step 11630: 0.0
# Accuracy at step 11640: 0.0
# Accuracy at step 11650: 0.0
# Accuracy at step 11660: 0.0
# Accuracy at step 11670: 0.0
# Accuracy at step 11680: 0.0
# Accuracy at step 11690: 0.0
# Accuracy at step 11700: 0.0
# Accuracy at step 11710: 0.0
# Accuracy at step 11720: 0.0
# Accuracy at step 11730: 0.0
# Accuracy at step 11740: 0.0
# Accuracy at step 11750: 0.0
# Accuracy at step 11760: 0.0
# Accuracy at step 11770: 0.0
# Accuracy at step 11780: 0.0
# Accuracy at step 11790: 0.0
# Accuracy at step 11800: 0.0
# Accuracy at step 11810: 0.0
# Accuracy at step 11820: 0.0
# Accuracy at step 11830: 0.0
# Accuracy at step 11840: 0.0
# Accuracy at step 11850: 0.0
# Accuracy at step 11860: 0.0
# Accuracy at step 11870: 0.0
# Accuracy at step 11880: 0.0
# Accuracy at step 11890: 0.0
# Accuracy at step 11900: 0.0
# Accuracy at step 11910: 0.0
# Accuracy at step 11920: 0.0
# Accuracy at step 11930: 0.0
# Accuracy at step 11940: 0.0
# Accuracy at step 11950: 0.0
# Accuracy at step 11960: 0.0
# Accuracy at step 11970: 0.0
# Accuracy at step 11980: 0.0
# Accuracy at step 11990: 0.0
# Accuracy at step 12000: 0.0
# Accuracy at step 12010: 0.0
# Accuracy at step 12020: 0.0
# Accuracy at step 12030: 0.0
# Accuracy at step 12040: 0.0
# Accuracy at step 12050: 0.0
# Accuracy at step 12060: 0.0
# Accuracy at step 12070: 0.0
# Accuracy at step 12080: 0.0
# Accuracy at step 12090: 0.0
# Accuracy at step 12100: 0.0
# Accuracy at step 12110: 0.0
# Accuracy at step 12120: 0.0
# Accuracy at step 12130: 0.0
# Accuracy at step 12140: 0.0
# Accuracy at step 12150: 0.0
# Accuracy at step 12160: 0.0
# Accuracy at step 12170: 0.0
# Accuracy at step 12180: 0.0
# Accuracy at step 12190: 0.0
# Accuracy at step 12200: 0.0
# Accuracy at step 12210: 0.0
# Accuracy at step 12220: 0.0
# Accuracy at step 12230: 0.0
# Accuracy at step 12240: 0.0
# Accuracy at step 12250: 0.0
# Accuracy at step 12260: 0.0
# Accuracy at step 12270: 0.0
# Accuracy at step 12280: 0.0
# Accuracy at step 12290: 0.0
# Accuracy at step 12300: 0.0
# Accuracy at step 12310: 0.0
# Accuracy at step 12320: 0.0
# Accuracy at step 12330: 0.0
# Accuracy at step 12340: 0.0
# Accuracy at step 12350: 0.0
# Accuracy at step 12360: 0.0
# Accuracy at step 12370: 0.0
# Accuracy at step 12380: 0.0
# Accuracy at step 12390: 0.0
# Accuracy at step 12400: 0.0
# Accuracy at step 12410: 0.0
# Accuracy at step 12420: 0.0
# Accuracy at step 12430: 0.0
# Accuracy at step 12440: 0.0
# Accuracy at step 12450: 0.0
# Accuracy at step 12460: 0.0
# Accuracy at step 12470: 0.0
# Accuracy at step 12480: 0.0
# Accuracy at step 12490: 0.0
# Accuracy at step 12500: 0.0
# Accuracy at step 12510: 0.0
# Accuracy at step 12520: 0.0
# Accuracy at step 12530: 0.0
# Accuracy at step 12540: 0.0
# Accuracy at step 12550: 0.0
# Accuracy at step 12560: 0.0
# Accuracy at step 12570: 0.0
# Accuracy at step 12580: 0.0
# Accuracy at step 12590: 0.0
# Accuracy at step 12600: 0.0
# Accuracy at step 12610: 0.0
# Accuracy at step 12620: 0.0
# Accuracy at step 12630: 0.0
# Accuracy at step 12640: 0.0
# Accuracy at step 12650: 0.0
# Accuracy at step 12660: 0.0
# Accuracy at step 12670: 0.0
# Accuracy at step 12680: 0.0
# Accuracy at step 12690: 0.0
# Accuracy at step 12700: 0.0
# Accuracy at step 12710: 0.0
# Accuracy at step 12720: 0.0
# Accuracy at step 12730: 0.0
# Accuracy at step 12740: 0.0
# Accuracy at step 12750: 0.0
# Accuracy at step 12760: 0.0
# Accuracy at step 12770: 0.0
# Accuracy at step 12780: 0.0
# Accuracy at step 12790: 0.0
# Accuracy at step 12800: 0.0
# Accuracy at step 12810: 0.0
# Accuracy at step 12820: 0.0
# Accuracy at step 12830: 0.0
# Accuracy at step 12840: 0.0
# Accuracy at step 12850: 0.0
# Accuracy at step 12860: 0.0
# Accuracy at step 12870: 0.0
# Accuracy at step 12880: 0.0
# Accuracy at step 12890: 0.0
# Accuracy at step 12900: 0.0
# Accuracy at step 12910: 0.0
# Accuracy at step 12920: 0.0
# Accuracy at step 12930: 0.0
# Accuracy at step 12940: 0.0
# Accuracy at step 12950: 0.0
# Accuracy at step 12960: 0.0
# Accuracy at step 12970: 0.0
# Accuracy at step 12980: 0.0
# Accuracy at step 12990: 0.0
# Accuracy at step 13000: 0.0
# Accuracy at step 13010: 0.0
# Accuracy at step 13020: 0.0
# Accuracy at step 13030: 0.0
# Accuracy at step 13040: 0.0
# Accuracy at step 13050: 0.0
# Accuracy at step 13060: 0.0
# Accuracy at step 13070: 0.0
# Accuracy at step 13080: 0.0
# Accuracy at step 13090: 0.0
# Accuracy at step 13100: 0.0
# Accuracy at step 13110: 0.0
# Accuracy at step 13120: 0.0
# Accuracy at step 13130: 0.0
# Accuracy at step 13140: 0.0
# Accuracy at step 13150: 0.0
# Accuracy at step 13160: 0.0
# Accuracy at step 13170: 0.0
# Accuracy at step 13180: 0.0
# Accuracy at step 13190: 0.0
# Accuracy at step 13200: 0.0
# Accuracy at step 13210: 0.0
# Accuracy at step 13220: 0.0
# Accuracy at step 13230: 0.0
# Accuracy at step 13240: 0.0
# Accuracy at step 13250: 0.0
# Accuracy at step 13260: 0.0
# Accuracy at step 13270: 0.0
# Accuracy at step 13280: 0.0
# Accuracy at step 13290: 0.0
# Accuracy at step 13300: 0.0
# Accuracy at step 13310: 0.0
# Accuracy at step 13320: 0.0
# Accuracy at step 13330: 0.0
# Accuracy at step 13340: 0.0
# Accuracy at step 13350: 0.0
# Accuracy at step 13360: 0.0
# Accuracy at step 13370: 0.0
# Accuracy at step 13380: 0.0
# Accuracy at step 13390: 0.0
# Accuracy at step 13400: 0.0
# Accuracy at step 13410: 0.0
# Accuracy at step 13420: 0.0
# Accuracy at step 13430: 0.0
# Accuracy at step 13440: 0.0
# Accuracy at step 13450: 0.0
# Accuracy at step 13460: 0.0
# Accuracy at step 13470: 0.0
# Accuracy at step 13480: 0.0
# Accuracy at step 13490: 0.0
# Accuracy at step 13500: 0.0
# Accuracy at step 13510: 0.0
# Accuracy at step 13520: 0.0
# Accuracy at step 13530: 0.0
# Accuracy at step 13540: 0.0
# Accuracy at step 13550: 0.0
# Accuracy at step 13560: 0.0
# Accuracy at step 13570: 0.0
# Accuracy at step 13580: 0.0
# Accuracy at step 13590: 0.0
# Accuracy at step 13600: 0.0
# Accuracy at step 13610: 0.0
# Accuracy at step 13620: 0.0
# Accuracy at step 13630: 0.0
# Accuracy at step 13640: 0.0
# Accuracy at step 13650: 0.0
# Accuracy at step 13660: 0.0
# Accuracy at step 13670: 0.0
# Accuracy at step 13680: 0.0
# Accuracy at step 13690: 0.0
# Accuracy at step 13700: 0.0
# Accuracy at step 13710: 0.0
# Accuracy at step 13720: 0.0
# Accuracy at step 13730: 0.0
# Accuracy at step 13740: 0.0
# Accuracy at step 13750: 0.0
# Accuracy at step 13760: 0.0
# Accuracy at step 13770: 0.0
# Accuracy at step 13780: 0.0
# Accuracy at step 13790: 0.0
# Accuracy at step 13800: 0.0
# Accuracy at step 13810: 0.0
# Accuracy at step 13820: 0.0
# Accuracy at step 13830: 0.0
# Accuracy at step 13840: 0.0
# Accuracy at step 13850: 0.0
# Accuracy at step 13860: 0.0
# Accuracy at step 13870: 0.0
# Accuracy at step 13880: 0.0
# Accuracy at step 13890: 0.0
# Accuracy at step 13900: 0.0
# Accuracy at step 13910: 0.0
# Accuracy at step 13920: 0.0
# Accuracy at step 13930: 0.0
# Accuracy at step 13940: 0.0
# Accuracy at step 13950: 0.0
# Accuracy at step 13960: 0.0
# Accuracy at step 13970: 1.0
# Accuracy at step 13980: 0.0
# Accuracy at step 13990: 0.0
# Accuracy at step 14000: 0.0
# Accuracy at step 14010: 0.0
# Accuracy at step 14020: 0.0
# Accuracy at step 14030: 0.0
# Accuracy at step 14040: 0.0
# Accuracy at step 14050: 0.0
# Accuracy at step 14060: 0.0
# Accuracy at step 14070: 0.0
# Accuracy at step 14080: 0.0
# Accuracy at step 14090: 0.0
# Accuracy at step 14100: 0.0
# Accuracy at step 14110: 0.0
# Accuracy at step 14120: 0.0
# Accuracy at step 14130: 0.0
# Accuracy at step 14140: 0.0
# Accuracy at step 14150: 0.0
# Accuracy at step 14160: 0.0
# Accuracy at step 14170: 0.0
# Accuracy at step 14180: 0.0
# Accuracy at step 14190: 0.0
# Accuracy at step 14200: 0.0
# Accuracy at step 14210: 0.0
# Accuracy at step 14220: 0.0
# Accuracy at step 14230: 0.0
# Accuracy at step 14240: 0.0
# Accuracy at step 14250: 0.0
# Accuracy at step 14260: 0.0
# Accuracy at step 14270: 0.0
# Accuracy at step 14280: 0.0
# Accuracy at step 14290: 0.0
# Accuracy at step 14300: 0.0
# Accuracy at step 14310: 0.0
# Accuracy at step 14320: 0.0
# Accuracy at step 14330: 0.0
# Accuracy at step 14340: 0.0
# Accuracy at step 14350: 0.0
# Accuracy at step 14360: 0.0
# Accuracy at step 14370: 0.0
# Accuracy at step 14380: 0.0
# Accuracy at step 14390: 0.0
# Accuracy at step 14400: 0.0
# Accuracy at step 14410: 0.0
# Accuracy at step 14420: 0.0
# Accuracy at step 14430: 0.0
# Accuracy at step 14440: 0.0
# Accuracy at step 14450: 0.0
# Accuracy at step 14460: 0.0
# Accuracy at step 14470: 0.0
# Accuracy at step 14480: 0.0
# Accuracy at step 14490: 0.0
# Accuracy at step 14500: 0.0
# Accuracy at step 14510: 0.0
# Accuracy at step 14520: 0.0
# Accuracy at step 14530: 0.0
# Accuracy at step 14540: 0.0
# Accuracy at step 14550: 0.0
# Accuracy at step 14560: 0.0
# Accuracy at step 14570: 0.0
# Accuracy at step 14580: 0.0
# Accuracy at step 14590: 0.0
# Accuracy at step 14600: 0.0
# Accuracy at step 14610: 0.0
# Accuracy at step 14620: 0.0
# Accuracy at step 14630: 0.0
# Accuracy at step 14640: 0.0
# Accuracy at step 14650: 0.0
# Accuracy at step 14660: 0.0
# Accuracy at step 14670: 0.0
# Accuracy at step 14680: 0.0
# Accuracy at step 14690: 0.0
# Accuracy at step 14700: 0.0
# Accuracy at step 14710: 0.0
# Accuracy at step 14720: 0.0
# Accuracy at step 14730: 0.0
# Accuracy at step 14740: 0.0
# Accuracy at step 14750: 0.0
# Accuracy at step 14760: 0.0
# Accuracy at step 14770: 0.0
# Accuracy at step 14780: 0.0
# Accuracy at step 14790: 0.0
# Accuracy at step 14800: 0.0
# Accuracy at step 14810: 0.0
# Accuracy at step 14820: 0.0
# Accuracy at step 14830: 0.0
# Accuracy at step 14840: 0.0
# Accuracy at step 14850: 0.0
# Accuracy at step 14860: 0.0
# Accuracy at step 14870: 0.0
# Accuracy at step 14880: 0.0
# Accuracy at step 14890: 0.0
# Accuracy at step 14900: 0.0
# Accuracy at step 14910: 0.0
# Accuracy at step 14920: 0.0
# Accuracy at step 14930: 0.0
# Accuracy at step 14940: 0.0
# Accuracy at step 14950: 0.0
# Accuracy at step 14960: 0.0
# Accuracy at step 14970: 0.0
# Accuracy at step 14980: 0.0
# Accuracy at step 14990: 0.0
# Accuracy at step 15000: 0.0
# Accuracy at step 15010: 0.0
# Accuracy at step 15020: 0.0
# Accuracy at step 15030: 0.0
# Accuracy at step 15040: 0.0
# Accuracy at step 15050: 0.0
# Accuracy at step 15060: 0.0
# Accuracy at step 15070: 0.0
# Accuracy at step 15080: 0.0
# Accuracy at step 15090: 0.0
# Accuracy at step 15100: 0.0
# Accuracy at step 15110: 0.0
# Accuracy at step 15120: 0.0
# Accuracy at step 15130: 0.0
# Accuracy at step 15140: 0.0
# Accuracy at step 15150: 0.0
# Accuracy at step 15160: 0.0
# Accuracy at step 15170: 0.0
# Accuracy at step 15180: 0.0
# Accuracy at step 15190: 0.0
# Accuracy at step 15200: 0.0
# Accuracy at step 15210: 0.0
# Accuracy at step 15220: 0.0
# Accuracy at step 15230: 0.0
# Accuracy at step 15240: 0.0
# Accuracy at step 15250: 0.0
# Accuracy at step 15260: 0.0
# Accuracy at step 15270: 0.0
# Accuracy at step 15280: 0.0
# Accuracy at step 15290: 0.0
# Accuracy at step 15300: 0.0
# Accuracy at step 15310: 0.0
# Accuracy at step 15320: 0.0
# Accuracy at step 15330: 0.0
# Accuracy at step 15340: 0.0
# Accuracy at step 15350: 0.0
# Accuracy at step 15360: 0.0
# Accuracy at step 15370: 0.0
# Accuracy at step 15380: 0.0
# Accuracy at step 15390: 0.0
# Accuracy at step 15400: 0.0
# Accuracy at step 15410: 0.0
# Accuracy at step 15420: 0.0
# Accuracy at step 15430: 0.0
# Accuracy at step 15440: 0.0
# Accuracy at step 15450: 0.0
# Accuracy at step 15460: 0.0
# Accuracy at step 15470: 0.0
# Accuracy at step 15480: 0.0
# Accuracy at step 15490: 0.0
# Accuracy at step 15500: 0.0
# Accuracy at step 15510: 0.0
# Accuracy at step 15520: 0.0
# Accuracy at step 15530: 0.0
# Accuracy at step 15540: 0.0
# Accuracy at step 15550: 0.0
# Accuracy at step 15560: 0.0
# Accuracy at step 15570: 0.0
# Accuracy at step 15580: 0.0
# Accuracy at step 15590: 0.0
# Accuracy at step 15600: 0.0
# Accuracy at step 15610: 0.0
# Accuracy at step 15620: 0.0
# Accuracy at step 15630: 0.0
# Accuracy at step 15640: 0.0
# Accuracy at step 15650: 0.0
# Accuracy at step 15660: 0.0
# Accuracy at step 15670: 0.0
# Accuracy at step 15680: 0.0
# Accuracy at step 15690: 0.0
# Accuracy at step 15700: 0.0
# Accuracy at step 15710: 0.0
# Accuracy at step 15720: 0.0
# Accuracy at step 15730: 0.0
# Accuracy at step 15740: 0.0
# Accuracy at step 15750: 0.0
# Accuracy at step 15760: 0.0
# Accuracy at step 15770: 0.0
# Accuracy at step 15780: 0.0
# Accuracy at step 15790: 0.0
# Accuracy at step 15800: 0.0
# Accuracy at step 15810: 0.0
# Accuracy at step 15820: 0.0
# Accuracy at step 15830: 0.0
# Accuracy at step 15840: 0.0
# Accuracy at step 15850: 0.0
# Accuracy at step 15860: 0.0
# Accuracy at step 15870: 0.0
# Accuracy at step 15880: 0.0
# Accuracy at step 15890: 0.0
# Accuracy at step 15900: 0.0
# Accuracy at step 15910: 0.0
# Accuracy at step 15920: 0.0
# Accuracy at step 15930: 0.0
# Accuracy at step 15940: 0.0
# Accuracy at step 15950: 0.0
# Accuracy at step 15960: 0.0
# Accuracy at step 15970: 0.0
# Accuracy at step 15980: 0.0
# Accuracy at step 15990: 0.0
# Accuracy at step 16000: 0.0
# Accuracy at step 16010: 0.0
# Accuracy at step 16020: 0.0
# Accuracy at step 16030: 0.0
# Accuracy at step 16040: 0.0
# Accuracy at step 16050: 0.0
# Accuracy at step 16060: 0.0
# Accuracy at step 16070: 0.0
# Accuracy at step 16080: 0.0
# Accuracy at step 16090: 0.0
# Accuracy at step 16100: 0.0
# Accuracy at step 16110: 0.0
# Accuracy at step 16120: 0.0
# Accuracy at step 16130: 0.0
# Accuracy at step 16140: 0.0
# Accuracy at step 16150: 0.0
# Accuracy at step 16160: 0.0
# Accuracy at step 16170: 0.0
# Accuracy at step 16180: 0.0
# Accuracy at step 16190: 0.0
# Accuracy at step 16200: 0.0
# Accuracy at step 16210: 0.0
# Accuracy at step 16220: 0.0
# Accuracy at step 16230: 0.0
# Accuracy at step 16240: 0.0
# Accuracy at step 16250: 0.0
# Accuracy at step 16260: 0.0
# Accuracy at step 16270: 0.0
# Accuracy at step 16280: 0.0
# Accuracy at step 16290: 0.0
# Accuracy at step 16300: 0.0
# Accuracy at step 16310: 0.0
# Accuracy at step 16320: 0.0
# Accuracy at step 16330: 0.0
# Accuracy at step 16340: 0.0
# Accuracy at step 16350: 0.0
# Accuracy at step 16360: 0.0
# Accuracy at step 16370: 0.0
# Accuracy at step 16380: 0.0
# Accuracy at step 16390: 0.0
# Accuracy at step 16400: 0.0
# Accuracy at step 16410: 0.0
# Accuracy at step 16420: 0.0
# Accuracy at step 16430: 0.0
# Accuracy at step 16440: 0.0
# Accuracy at step 16450: 0.0
# Accuracy at step 16460: 0.0
# Accuracy at step 16470: 0.0
# Accuracy at step 16480: 0.0
# Accuracy at step 16490: 0.0
# Accuracy at step 16500: 0.0
# Accuracy at step 16510: 0.0
# Accuracy at step 16520: 0.0
# Accuracy at step 16530: 0.0
# Accuracy at step 16540: 0.0
# Accuracy at step 16550: 0.0
# Accuracy at step 16560: 0.0
# Accuracy at step 16570: 0.0
# Accuracy at step 16580: 0.0
# Accuracy at step 16590: 0.0
# Accuracy at step 16600: 0.0
# Accuracy at step 16610: 0.0
# Accuracy at step 16620: 0.0
# Accuracy at step 16630: 0.0
# Accuracy at step 16640: 0.0
# Accuracy at step 16650: 0.0
# Accuracy at step 16660: 0.0
# Accuracy at step 16670: 0.0
# Accuracy at step 16680: 0.0
# Accuracy at step 16690: 0.0
# Accuracy at step 16700: 0.0
# Accuracy at step 16710: 0.0
# Accuracy at step 16720: 0.0
# Accuracy at step 16730: 0.0
# Accuracy at step 16740: 0.0
# Accuracy at step 16750: 0.0
# Accuracy at step 16760: 0.0
# Accuracy at step 16770: 0.0
# Accuracy at step 16780: 0.0
# Accuracy at step 16790: 0.0
# Accuracy at step 16800: 0.0
# Accuracy at step 16810: 0.0
# Accuracy at step 16820: 0.0
# Accuracy at step 16830: 0.0
# Accuracy at step 16840: 0.0
# Accuracy at step 16850: 0.0
# Accuracy at step 16860: 0.0
# Accuracy at step 16870: 0.0
# Accuracy at step 16880: 0.0
# Accuracy at step 16890: 0.0
# Accuracy at step 16900: 0.0
# Accuracy at step 16910: 0.0
# Accuracy at step 16920: 0.0
# Accuracy at step 16930: 0.0
# Accuracy at step 16940: 0.0
# Accuracy at step 16950: 0.0
# Accuracy at step 16960: 0.0
# Accuracy at step 16970: 0.0
# Accuracy at step 16980: 0.0
# Accuracy at step 16990: 0.0
# Accuracy at step 17000: 0.0
# Accuracy at step 17010: 0.0
# Accuracy at step 17020: 0.0
# Accuracy at step 17030: 0.0
# Accuracy at step 17040: 0.0
# Accuracy at step 17050: 0.0
# Accuracy at step 17060: 0.0
# Accuracy at step 17070: 0.0
# Accuracy at step 17080: 0.0
# Accuracy at step 17090: 0.0
# Accuracy at step 17100: 0.0
# Accuracy at step 17110: 0.0
# Accuracy at step 17120: 0.0
# Accuracy at step 17130: 0.0
# Accuracy at step 17140: 0.0
# Accuracy at step 17150: 0.0
# Accuracy at step 17160: 0.0
# Accuracy at step 17170: 0.0
# Accuracy at step 17180: 0.0
# Accuracy at step 17190: 0.0
# Accuracy at step 17200: 0.0
# Accuracy at step 17210: 0.0
# Accuracy at step 17220: 0.0
# Accuracy at step 17230: 0.0
# Accuracy at step 17240: 0.0
# Accuracy at step 17250: 0.0
# Accuracy at step 17260: 0.0
# Accuracy at step 17270: 0.0
# Accuracy at step 17280: 0.0
# Accuracy at step 17290: 0.0
# Accuracy at step 17300: 0.0
# Accuracy at step 17310: 0.0
# Accuracy at step 17320: 0.0
# Accuracy at step 17330: 0.0
# Accuracy at step 17340: 0.0
# Accuracy at step 17350: 0.0
# Accuracy at step 17360: 0.0
# Accuracy at step 17370: 0.0
# Accuracy at step 17380: 0.0
# Accuracy at step 17390: 0.0
# Accuracy at step 17400: 0.0
# Accuracy at step 17410: 0.0
# Accuracy at step 17420: 0.0
# Accuracy at step 17430: 0.0
# Accuracy at step 17440: 0.0
# Accuracy at step 17450: 0.0
# Accuracy at step 17460: 0.0
# Accuracy at step 17470: 0.0
# Accuracy at step 17480: 0.0
# Accuracy at step 17490: 0.0
# Accuracy at step 17500: 0.0
# Accuracy at step 17510: 0.0
# Accuracy at step 17520: 0.0
# Accuracy at step 17530: 0.0
# Accuracy at step 17540: 0.0
# ...
# Accuracy at step 18790: 0.0
# Accuracy at step 18800: 0.0
# Accuracy at step 18810: 0.0
# Accuracy at step 18820: 0.0
# Accuracy at step 18830: 0.0
# Accuracy at step 18840: 0.0
# Accuracy at step 18850: 0.0
# Accuracy at step 18860: 0.0
# Accuracy at step 18870: 0.0
# Accuracy at step 18880: 0.0
# Accuracy at step 18890: 0.0
# Accuracy at step 18900: 0.0
# Accuracy at step 18910: 0.0
# Accuracy at step 18920: 0.0
# Accuracy at step 18930: 0.0
# Accuracy at step 18940: 0.0
# Accuracy at step 18950: 0.0
# Accuracy at step 18960: 0.0
# Accuracy at step 18970: 0.0
# Accuracy at step 18980: 0.0
# Accuracy at step 18990: 0.0
# Accuracy at step 19000: 0.0
# Accuracy at step 19010: 0.0
# Accuracy at step 19020: 0.0
# Accuracy at step 19030: 0.0
# Accuracy at step 19040: 0.0
# Accuracy at step 19050: 0.0
# Accuracy at step 19060: 0.0
# Accuracy at step 19070: 0.0
# Accuracy at step 19080: 0.0
# Accuracy at step 19090: 0.0
# Accuracy at step 19100: 0.0
# Accuracy at step 19110: 0.0
# Accuracy at step 19120: 0.0
# Accuracy at step 19130: 0.0
# Accuracy at step 19140: 0.0
# Accuracy at step 19150: 0.0
# Accuracy at step 19160: 0.0
# Accuracy at step 19170: 0.0
# Accuracy at step 19180: 0.0
# Accuracy at step 19190: 0.0
# Accuracy at step 19200: 0.0
# Accuracy at step 19210: 0.0
# Accuracy at step 19220: 0.0
# Accuracy at step 19230: 0.0
# Accuracy at step 19240: 0.0
# Accuracy at step 19250: 0.0
# Accuracy at step 19260: 0.0
# Accuracy at step 19270: 0.0
# Accuracy at step 19280: 0.0
# Accuracy at step 19290: 0.0
# Accuracy at step 19300: 0.0
# Accuracy at step 19310: 0.0
# Accuracy at step 19320: 0.0
# Accuracy at step 19330: 0.0
# Accuracy at step 19340: 0.0
# Accuracy at step 19350: 0.0
# Accuracy at step 19360: 0.0
# Accuracy at step 19370: 0.0
# Accuracy at step 19380: 0.0
# Accuracy at step 19390: 0.0
# Accuracy at step 19400: 0.0
# Accuracy at step 19410: 0.0
# Accuracy at step 19420: 0.0
# Accuracy at step 19430: 0.0
# Accuracy at step 19440: 0.0
# Accuracy at step 19450: 0.0
# Accuracy at step 19460: 0.0
# Accuracy at step 19470: 0.0
# Accuracy at step 19480: 0.0
# Accuracy at step 19490: 0.0
# Accuracy at step 19500: 0.0
# Accuracy at step 19510: 0.0
# Accuracy at step 19520: 0.0
# Accuracy at step 19530: 0.0
# Accuracy at step 19540: 0.0
# Accuracy at step 19550: 0.0
# Accuracy at step 19560: 0.0
# Accuracy at step 19570: 0.0
# Accuracy at step 19580: 0.0
# Accuracy at step 19590: 0.0
# Accuracy at step 19600: 0.0
# Accuracy at step 19610: 0.0
# Accuracy at step 19620: 0.0
# Accuracy at step 19630: 0.0
# Accuracy at step 19640: 0.0
# Accuracy at step 19650: 0.0
# Accuracy at step 19660: 0.0
# Accuracy at step 19670: 0.0
# Accuracy at step 19680: 0.0
# Accuracy at step 19690: 0.0
# Accuracy at step 19700: 0.0
# Accuracy at step 19710: 0.0
# Accuracy at step 19720: 0.0
# Accuracy at step 19730: 0.0
# Accuracy at step 19740: 0.0
# Accuracy at step 19750: 0.0
# Accuracy at step 19760: 0.0
# Accuracy at step 19770: 0.0
# Accuracy at step 19780: 0.0
# Accuracy at step 19790: 0.0
# Accuracy at step 19800: 0.0
# Accuracy at step 19810: 0.0
# Accuracy at step 19820: 0.0
# Accuracy at step 19830: 0.0
# Accuracy at step 19840: 0.0
# Accuracy at step 19850: 0.0
# Accuracy at step 19860: 0.0
# Accuracy at step 19870: 0.0
# Accuracy at step 19880: 0.0
# Accuracy at step 19890: 0.0
# Accuracy at step 19900: 0.0
# Accuracy at step 19910: 0.0
# Accuracy at step 19920: 0.0
# Accuracy at step 19930: 0.0
# Accuracy at step 19940: 0.0
# Accuracy at step 19950: 0.0
# Accuracy at step 19960: 0.0
# Accuracy at step 19970: 0.0
# Accuracy at step 19980: 0.0
# Accuracy at step 19990: 0.0
# Accuracy at step 20000: 0.0
# Accuracy at step 20010: 0.0
# Accuracy at step 20020: 0.0
# Accuracy at step 20030: 0.0
# Accuracy at step 20040: 0.0
# Accuracy at step 20050: 0.0
# Accuracy at step 20060: 0.0
# Accuracy at step 20070: 0.0
# Accuracy at step 20080: 0.0
# Accuracy at step 20090: 0.0
# Accuracy at step 20100: 0.0
# Accuracy at step 20110: 0.0
# Accuracy at step 20120: 0.0
# Accuracy at step 20130: 0.0
# Accuracy at step 20140: 0.0
# Accuracy at step 20150: 0.0
# Accuracy at step 20160: 0.0
# Accuracy at step 20170: 0.0
# Accuracy at step 20180: 0.0
# Accuracy at step 20190: 0.0
# Accuracy at step 20200: 0.0
# Accuracy at step 20210: 0.0
# Accuracy at step 20220: 0.0
# Accuracy at step 20230: 0.0
# Accuracy at step 20240: 0.0
# Accuracy at step 20250: 0.0
# Accuracy at step 20260: 0.0
# Accuracy at step 20270: 0.0
# Accuracy at step 20280: 0.0
# Accuracy at step 20290: 0.0
# Accuracy at step 20300: 0.0
# Accuracy at step 20310: 0.0
# Accuracy at step 20320: 0.0
# Accuracy at step 20330: 0.0
# Accuracy at step 20340: 0.0
# Accuracy at step 20350: 0.0
# Accuracy at step 20360: 0.0
# Accuracy at step 20370: 0.0
# Accuracy at step 20380: 0.0
# Accuracy at step 20390: 0.0
# Accuracy at step 20400: 0.0
# Accuracy at step 20410: 0.0
# Accuracy at step 20420: 0.0
# Accuracy at step 20430: 0.0
# Accuracy at step 20440: 0.0
# Accuracy at step 20450: 0.0
# Accuracy at step 20460: 0.0
# Accuracy at step 20470: 0.0
# Accuracy at step 20480: 0.0
# Accuracy at step 20490: 0.0
# Accuracy at step 20500: 0.0
# Accuracy at step 20510: 0.0
# Accuracy at step 20520: 0.0
# Accuracy at step 20530: 0.0
# Accuracy at step 20540: 0.0
# Accuracy at step 20550: 0.0
# Accuracy at step 20560: 0.0
# Accuracy at step 20570: 0.0
# Accuracy at step 20580: 0.0
# Accuracy at step 20590: 0.0
# Accuracy at step 20600: 0.0
# Accuracy at step 20610: 0.0
# Accuracy at step 20620: 0.0
# Accuracy at step 20630: 0.0
# Accuracy at step 20640: 0.0
# Accuracy at step 20650: 0.0
# Accuracy at step 20660: 0.0
# Accuracy at step 20670: 0.0
# Accuracy at step 20680: 0.0
# Accuracy at step 20690: 0.0
# Accuracy at step 20700: 0.0
# Accuracy at step 20710: 0.0
# Accuracy at step 20720: 0.0
# Accuracy at step 20730: 0.0
# Accuracy at step 20740: 0.0
# Accuracy at step 20750: 0.0
# Accuracy at step 20760: 0.0
# Accuracy at step 20770: 0.0
# Accuracy at step 20780: 0.0
# Accuracy at step 20790: 0.0
# Accuracy at step 20800: 0.0
# Accuracy at step 20810: 0.0
# Accuracy at step 20820: 0.0
# Accuracy at step 20830: 0.0
# Accuracy at step 20840: 0.0
# Accuracy at step 20850: 0.0
# Accuracy at step 20860: 0.0
# Accuracy at step 20870: 0.0
# Accuracy at step 20880: 0.0
# Accuracy at step 20890: 0.0
# Accuracy at step 20900: 0.0
# Accuracy at step 20910: 0.0
# Accuracy at step 20920: 0.0
# Accuracy at step 20930: 0.0
# Accuracy at step 20940: 0.0
# Accuracy at step 20950: 0.0
# Accuracy at step 20960: 0.0
# Accuracy at step 20970: 0.0
# Accuracy at step 20980: 0.0
# Accuracy at step 20990: 0.0
# Accuracy at step 21000: 0.0
# Accuracy at step 21010: 0.0
# Accuracy at step 21020: 0.0
# Accuracy at step 21030: 0.0
# Accuracy at step 21040: 0.0
# Accuracy at step 21050: 0.0
# Accuracy at step 21060: 0.0
# Accuracy at step 21070: 0.0
# Accuracy at step 21080: 0.0
# Accuracy at step 21090: 0.0
# Accuracy at step 21100: 0.0
# Accuracy at step 21110: 0.0
# Accuracy at step 21120: 0.0
# Accuracy at step 21130: 0.0
# Accuracy at step 21140: 0.0
# Accuracy at step 21150: 0.0
# Accuracy at step 21160: 0.0
# Accuracy at step 21170: 0.0
# Accuracy at step 21180: 0.0
# Accuracy at step 21190: 0.0
# Accuracy at step 21200: 0.0
# Accuracy at step 21210: 0.0
# Accuracy at step 21220: 0.0
# Accuracy at step 21230: 0.0
# Accuracy at step 21240: 0.0
# Accuracy at step 21250: 0.0
# Accuracy at step 21260: 0.0
# Accuracy at step 21270: 0.0
# Accuracy at step 21280: 0.0
# Accuracy at step 21290: 0.0
# Accuracy at step 21300: 0.0
# Accuracy at step 21310: 0.0
# Accuracy at step 21320: 0.0
# Accuracy at step 21330: 0.0
# Accuracy at step 21340: 0.0
# Accuracy at step 21350: 0.0
# Accuracy at step 21360: 0.0
# Accuracy at step 21370: 0.0
# Accuracy at step 21380: 0.0
# Accuracy at step 21390: 0.0
# Accuracy at step 21400: 0.0
# Accuracy at step 21410: 0.0
# Accuracy at step 21420: 0.0
# Accuracy at step 21430: 0.0
# Accuracy at step 21440: 0.0
# Accuracy at step 21450: 0.0
# Accuracy at step 21460: 0.0
# Accuracy at step 21470: 0.0
# Accuracy at step 21480: 0.0
# Accuracy at step 21490: 0.0
# Accuracy at step 21500: 0.0
# Accuracy at step 21510: 0.0
# Accuracy at step 21520: 0.0
# Accuracy at step 21530: 0.0
# Accuracy at step 21540: 0.0
# Accuracy at step 21550: 0.0
# Accuracy at step 21560: 0.0
# Accuracy at step 21570: 0.0
# Accuracy at step 21580: 0.0
# Accuracy at step 21590: 0.0
# Accuracy at step 21600: 0.0
# Accuracy at step 21610: 0.0
# Accuracy at step 21620: 0.0
# Accuracy at step 21630: 0.0
# Accuracy at step 21640: 0.0
# Accuracy at step 21650: 0.0
# Accuracy at step 21660: 0.0
# Accuracy at step 21670: 0.0
# Accuracy at step 21680: 0.0
# Accuracy at step 21690: 0.0
# Accuracy at step 21700: 0.0
# Accuracy at step 21710: 0.0
# Accuracy at step 21720: 0.0
# Accuracy at step 21730: 0.0
# Accuracy at step 21740: 0.0
# Accuracy at step 21750: 0.0
# Accuracy at step 21760: 0.0
# Accuracy at step 21770: 0.0
# Accuracy at step 21780: 0.0
# Accuracy at step 21790: 0.0
# Accuracy at step 21800: 0.0
# Accuracy at step 21810: 0.0
# Accuracy at step 21820: 0.0
# Accuracy at step 21830: 0.0
# Accuracy at step 21840: 0.0
# Accuracy at step 21850: 0.0
# Accuracy at step 21860: 0.0
# Accuracy at step 21870: 0.0
# Accuracy at step 21880: 0.0
# Accuracy at step 21890: 0.0
# Accuracy at step 21900: 0.0
# Accuracy at step 21910: 0.0
# Accuracy at step 21920: 0.0
# Accuracy at step 21930: 0.0
# Accuracy at step 21940: 0.0
# Accuracy at step 21950: 0.0
# Accuracy at step 21960: 0.0
# Accuracy at step 21970: 0.0
# Accuracy at step 21980: 0.0
# Accuracy at step 21990: 0.0
# Accuracy at step 22000: 0.0
# Accuracy at step 22010: 0.0
# Accuracy at step 22020: 0.0
# Accuracy at step 22030: 0.0
# Accuracy at step 22040: 0.0
# Accuracy at step 22050: 0.0
# Accuracy at step 22060: 0.0
# Accuracy at step 22070: 0.0
# Accuracy at step 22080: 0.0
# Accuracy at step 22090: 0.0
# Accuracy at step 22100: 0.0
# Accuracy at step 22110: 0.0
# Accuracy at step 22120: 0.0
# Accuracy at step 22130: 0.0
# Accuracy at step 22140: 0.0
# Accuracy at step 22150: 0.0
# Accuracy at step 22160: 0.0
# Accuracy at step 22170: 0.0
# Accuracy at step 22180: 0.0
# Accuracy at step 22190: 0.0
# Accuracy at step 22200: 0.0
# Accuracy at step 22210: 0.0
# Accuracy at step 22220: 0.0
# Accuracy at step 22230: 0.0
# Accuracy at step 22240: 0.0
# Accuracy at step 22250: 0.0
# Accuracy at step 22260: 0.0
# Accuracy at step 22270: 0.0
# Accuracy at step 22280: 0.0
# Accuracy at step 22290: 0.0
# Accuracy at step 22300: 0.0
# Accuracy at step 22310: 0.0
# Accuracy at step 22320: 0.0
# Accuracy at step 22330: 0.0
# Accuracy at step 22340: 0.0
# Accuracy at step 22350: 0.0
# Accuracy at step 22360: 0.0
# Accuracy at step 22370: 0.0
# Accuracy at step 22380: 0.0
# Accuracy at step 22390: 0.0
# Accuracy at step 22400: 0.0
# Accuracy at step 22410: 0.0
# Accuracy at step 22420: 0.0
# Accuracy at step 22430: 0.0
# Accuracy at step 22440: 0.0
# Accuracy at step 22450: 0.0
# Accuracy at step 22460: 0.0
# Accuracy at step 22470: 0.0
# Accuracy at step 22480: 0.0
# Accuracy at step 22490: 0.0
# Accuracy at step 22500: 0.0
# Accuracy at step 22510: 0.0
# Accuracy at step 22520: 0.0
# Accuracy at step 22530: 0.0
# Accuracy at step 22540: 0.0
# Accuracy at step 22550: 0.0
# Accuracy at step 22560: 0.0
# Accuracy at step 22570: 0.0
# Accuracy at step 22580: 0.0
# Accuracy at step 22590: 0.0
# Accuracy at step 22600: 0.0
# Accuracy at step 22610: 0.0
# Accuracy at step 22620: 0.0
# Accuracy at step 22630: 0.0
# Accuracy at step 22640: 0.0
# Accuracy at step 22650: 0.0
# Accuracy at step 22660: 0.0
# Accuracy at step 22670: 0.0
# Accuracy at step 22680: 0.0
# Accuracy at step 22690: 0.0
# Accuracy at step 22700: 0.0
# Accuracy at step 22710: 0.0
# Accuracy at step 22720: 0.0
# Accuracy at step 22730: 0.0
# Accuracy at step 22740: 0.0
# Accuracy at step 22750: 0.0
# Accuracy at step 22760: 0.0
# Accuracy at step 22770: 0.0
# Accuracy at step 22780: 0.0
# Accuracy at step 22790: 0.0
# Accuracy at step 22800: 0.0
# Accuracy at step 22810: 0.0
# Accuracy at step 22820: 0.0
# Accuracy at step 22830: 0.0
# Accuracy at step 22840: 0.0
# Accuracy at step 22850: 0.0
# Accuracy at step 22860: 0.0
# Accuracy at step 22870: 0.0
# Accuracy at step 22880: 0.0
# Accuracy at step 22890: 0.0
# Accuracy at step 22900: 0.0
# Accuracy at step 22910: 0.0
# Accuracy at step 22920: 0.0
# Accuracy at step 22930: 0.0
# Accuracy at step 22940: 0.0
# Accuracy at step 22950: 0.0
# Accuracy at step 22960: 0.0
# Accuracy at step 22970: 0.0
# Accuracy at step 22980: 0.0
# Accuracy at step 22990: 0.0
# Accuracy at step 23000: 0.0
# Accuracy at step 23010: 0.0
# Accuracy at step 23020: 0.0
# Accuracy at step 23030: 0.0
# Accuracy at step 23040: 0.0
# Accuracy at step 23050: 0.0
# Accuracy at step 23060: 0.0
# Accuracy at step 23070: 0.0
# Accuracy at step 23080: 0.0
# Accuracy at step 23090: 0.0
# Accuracy at step 23100: 0.0
# Accuracy at step 23110: 0.0
# Accuracy at step 23120: 0.0
# Accuracy at step 23130: 0.0
# Accuracy at step 23140: 0.0
# Accuracy at step 23150: 0.0
# Accuracy at step 23160: 0.0
# Accuracy at step 23170: 0.0
# Accuracy at step 23180: 0.0
# Accuracy at step 23190: 0.0
# Accuracy at step 23200: 0.0
# Accuracy at step 23210: 0.0
# Accuracy at step 23220: 0.0
# Accuracy at step 23230: 0.0
# Accuracy at step 23240: 0.0
# Accuracy at step 23250: 0.0
# Accuracy at step 23260: 0.0
# Accuracy at step 23270: 0.0
# Accuracy at step 23280: 0.0
# Accuracy at step 23290: 0.0
# Accuracy at step 23300: 0.0
# Accuracy at step 23310: 0.0
# Accuracy at step 23320: 0.0
# Accuracy at step 23330: 0.0
# Accuracy at step 23340: 0.0
# Accuracy at step 23350: 0.0
# Accuracy at step 23360: 0.0
# Accuracy at step 23370: 0.0
# Accuracy at step 23380: 0.0
# Accuracy at step 23390: 0.0
# Accuracy at step 23400: 0.0
# Accuracy at step 23410: 0.0
# Accuracy at step 23420: 0.0
# Accuracy at step 23430: 0.0
# Accuracy at step 23440: 0.0
# Accuracy at step 23450: 0.0
# Accuracy at step 23460: 0.0
# Accuracy at step 23470: 0.0
# Accuracy at step 23480: 0.0
# Accuracy at step 23490: 0.0
# Accuracy at step 23500: 0.0
# Accuracy at step 23510: 0.0
# Accuracy at step 23520: 0.0
# Accuracy at step 23530: 0.0
# Accuracy at step 23540: 0.0
# Accuracy at step 23550: 0.0
# Accuracy at step 23560: 0.0
# Accuracy at step 23570: 0.0
# Accuracy at step 23580: 0.0
# Accuracy at step 23590: 0.0
# Accuracy at step 23600: 0.0
# Accuracy at step 23610: 0.0
# Accuracy at step 23620: 0.0
# Accuracy at step 23630: 0.0
# Accuracy at step 23640: 0.0
# Accuracy at step 23650: 0.0
# Accuracy at step 23660: 0.0
# Accuracy at step 23670: 0.0
# Accuracy at step 23680: 0.0
# Accuracy at step 23690: 0.0
# Accuracy at step 23700: 0.0
# Accuracy at step 23710: 0.0
# Accuracy at step 23720: 0.0
# Accuracy at step 23730: 0.0
# Accuracy at step 23740: 0.0
# Accuracy at step 23750: 0.0
# Accuracy at step 23760: 0.0
# Accuracy at step 23770: 0.0
# Accuracy at step 23780: 0.0
# Accuracy at step 23790: 0.0
# Accuracy at step 23800: 0.0
# Accuracy at step 23810: 0.0
# Accuracy at step 23820: 0.0
# Accuracy at step 23830: 0.0
# Accuracy at step 23840: 0.0
# Accuracy at step 23850: 0.0
# Accuracy at step 23860: 0.0
# Accuracy at step 23870: 0.0
# Accuracy at step 23880: 0.0
# Accuracy at step 23890: 0.0
# Accuracy at step 23900: 0.0
# Accuracy at step 23910: 0.0
# Accuracy at step 23920: 0.0
# Accuracy at step 23930: 0.0
# Accuracy at step 23940: 0.0
# Accuracy at step 23950: 0.0
# Accuracy at step 23960: 0.0
# Accuracy at step 23970: 0.0
# Accuracy at step 23980: 0.0
# Accuracy at step 23990: 0.0
# Accuracy at step 24000: 0.0
# Accuracy at step 24010: 0.0
# Accuracy at step 24020: 0.0
# Accuracy at step 24030: 0.0
# Accuracy at step 24040: 0.0
# Accuracy at step 24050: 0.0
# Accuracy at step 24060: 0.0
# Accuracy at step 24070: 0.0
# Accuracy at step 24080: 0.0
# Accuracy at step 24090: 0.0
# Accuracy at step 24100: 0.0
# Accuracy at step 24110: 0.0
# Accuracy at step 24120: 0.0
# Accuracy at step 24130: 0.0
# Accuracy at step 24140: 0.0
# Accuracy at step 24150: 0.0
# Accuracy at step 24160: 0.0
# Accuracy at step 24170: 0.0
# Accuracy at step 24180: 0.0
# Accuracy at step 24190: 0.0
# Accuracy at step 24200: 0.0
# Accuracy at step 24210: 0.0
# Accuracy at step 24220: 0.0
# Accuracy at step 24230: 0.0
# Accuracy at step 24240: 0.0
# Accuracy at step 24250: 0.0
# Accuracy at step 24260: 0.0
# Accuracy at step 24270: 0.0
# Accuracy at step 24280: 0.0
# Accuracy at step 24290: 0.0
# Accuracy at step 24300: 0.0
# Accuracy at step 24310: 0.0
# Accuracy at step 24320: 0.0
# Accuracy at step 24330: 0.0
# Accuracy at step 24340: 0.0
# Accuracy at step 24350: 0.0
# Accuracy at step 24360: 0.0
# Accuracy at step 24370: 0.0
# Accuracy at step 24380: 0.0
# Accuracy at step 24390: 0.0
# Accuracy at step 24400: 0.0
# Accuracy at step 24410: 0.0
# Accuracy at step 24420: 0.0
# Accuracy at step 24430: 0.0
# Accuracy at step 24440: 0.0
# Accuracy at step 24450: 0.0
# Accuracy at step 24460: 0.0
# Accuracy at step 24470: 0.0
# Accuracy at step 24480: 0.0
# Accuracy at step 24490: 0.0

# %%
def one_hot_to_class(one_hot):
    for key, value in enumerate(one_hot):
        if value > 0:
            return indexes_to_classes[key]

# %%
x_1, y_1 = get_batch(train_filenames, batch_size, image_size, num_classes, True)
results = y_conv.eval(feed_dict={x: x_1, y_: y_1, keep_prob: 1., })

# %%
for a in range(20):
    show_image(x_1[a,:,:,:])
    print("Actual: " + one_hot_to_class(y_1[a]))
    print("Guess: " + one_hot_to_class(results[a]))

# %%
# %%timeit
x_1, y_1 = get_batch(train_filenames, batch_size, image_size, num_classes)
# Out:
# 1 loop, best of 3: 3.16 s per loop

# %%
# Weight decay, batch normalization, bigger network, different filter sizes, inception filters
# sgd with momentum seems standard

# %%
# Simple network definition (intended for CIFAR-10?)
sess = tf.InteractiveSession()

# Placeholder for the image size
#image_size_variable = tf.placeholder(tf.float32)

# Batched input
x = tf.placeholder(tf.float32, shape=[None, image_size, image_size, image_depth]) # batch size, image size, image size, image depth
y_ = tf.placeholder(tf.float32, shape=[None, num_classes]) # batch size, num_classes

W_conv1 = weight_variable([5, 5, image_depth, 32]) # filter size, filter size, input channels (image depth), output channels
b_conv1 = bias_variable([32])

#x_image = tf.reshape(x, [batch_size,28,28,1])

h_conv1 = tf.nn.relu(conv2d(x, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fc1 = weight_variable([int(image_size/4) * int(image_size/4) * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, int(image_size/4) * int(image_size/4)*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# Dropout
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# Softmax
W_fc2 = weight_variable([1024, num_classes])
b_fc2 = bias_variable([num_classes])

y_conv=tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

# %%
# %%timeit
# How long does it take to load a batch?
x_1, y_1 = get_batch(train_filenames, batch_size, image_size, num_classes)
# Out:
# 1 loop, best of 3: 1.82 s per loop

# %%
image_index
# Out:
# 1536
