# %%
import xml
import numpy as np
from pylab import *
# %matplotlib inline
import xml.etree.ElementTree as ET
import cv2

# %%
import os
home_dir = os.path.expanduser('~') + "/"
datasets_dir = home_dir + "external_drive/"
voc_2012_dir = datasets_dir + "VOC/VOC2012/VOCdevkit/VOC2012/"
print(voc_2012_dir)
# Out:
# /home/ubuntu/external_drive/VOC/VOC2012/VOCdevkit/VOC2012/

# %%
# Get list of training images
train_filenames = []
with open(voc_2012_dir + "ImageSets/Main/train.txt", "r") as file:
    for line in file:
        train_filenames.append(line.strip())

# %%
train_filenames[:10]
# Out:
# ['2008_000008',
#  '2008_000015',
#  '2008_000019',
#  '2008_000023',
#  '2008_000028',
#  '2008_000033',
#  '2008_000036',
#  '2008_000037',
#  '2008_000041',
#  '2008_000045']

# %%
class bounding_box:
    def __init__(self, class_name, bbox_coords):
        self.class_name = class_name
        self.bbox_coords = bbox_coords #xmax, xmin, ymax, ymin

# %%
# Read an annotation file, return a list of bounding boxes
def read_annotation(filename):
    bounding_boxes = []
    xmldoc = ET.parse(voc_2012_dir + "Annotations/{}.xml".format(filename))
    objects = xmldoc.findall('object')
    for thing in objects:
        name = thing.find('name').text
        box = thing.find('bndbox')
        xmax = box.find('xmax').text
        xmin = box.find('xmin').text
        ymax = box.find('ymax').text
        ymin = box.find('ymin').text
        bounding_boxes.append(bounding_box(name, (xmax, xmin, ymax, ymin))) 
    return bounding_boxes
#read_annotation("2011_005768")

# %%
read_annotation("2011_005768")[0].class_name
# Out:
# 'person'

# %%
for item in filenames[:10]:
    print(len(read_annotation(item)))
# Out:
# 2
# 2
# 3
# 5
# 2
# 1
# 5
# 1
# 12
# 1

# %%
def read_jpeg(filename):
    image = cv2.imread(voc_2012_dir + "JPEGImages/{}.jpg".format(filename))
    if image is None:
        print("Failed to read image! This is probably bad")
    # Convert BGR to RGB. 
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(read_jpeg("2011_005768"))

# %%
RGB
BGR

# %%
output.shape
# Out:
# (370, 500, 3)

# %%
RGB
RBG
